# %%
import pandas as pd
from glob import glob
import os

# %%
csv_files = glob('./data/census_tracts/*.csv')

csv_dict = {}
states_list = []

for filename in csv_files:
    filename_cleaned = os.path.basename(filename).replace('.csv', "")
    states_list.append(filename_cleaned.rpartition('_t')[0])
    filename_df = pd.read_csv(filename)
    csv_dict[filename_cleaned] = filename_df

# %%
len(csv_dict)
# Out:
# 43

# %%
states_list.pop(0)
# Out:
# 'MN'

# %%
tracts_df = csv_dict['MN_tracts']

for state in states_list:
    tracts_df = pd.concat([tracts_df, csv_dict[state+'_tracts']])

# %%
tracts_df['name'] = tracts_df['name'].astype(str)+'_'+tracts_df['parent.location'].str.rpartition(', ')[0]

# %%
tracts_df['state'] = tracts_df['parent.location'].str.rpartition(', ')[2]

# %%
tracts_df
# Out:
#             GEOID  year                    name            parent.location  \
# 0     27003050107  2012     501.07_Anoka County    Anoka County, Minnesota
# 1     27003050108  2012     501.08_Anoka County    Anoka County, Minnesota
# 2     27003050109  2012     501.09_Anoka County    Anoka County, Minnesota
# 3     27003050110  2012      501.1_Anoka County    Anoka County, Minnesota
# 4     27003050111  2012     501.11_Anoka County    Anoka County, Minnesota
# ...           ...   ...                     ...                        ...
# 5191  36085990100  2003  9901.0_Richmond County  Richmond County, New York
# 5192  36085990100  2004  9901.0_Richmond County  Richmond County, New York
# 5193  36085990100  2005  9901.0_Richmond County  Richmond County, New York
# 5194  36085990100  2006  9901.0_Richmond County  Richmond County, New York
# 5195  36085990100  2016  9901.0_Richmond County  Richmond County, New York
#
#       population  poverty.rate  renter.occupied.households  \
# 0         2832.0          0.81                        83.0
# 1         4931.0          8.39                       311.0
# 2         5141.0          2.45                        87.0
# 3         2665.0          8.26                        53.0
# 4         3819.0          1.11                        74.0
# ...          ...           ...                         ...
# 5191         0.0          0.00                         0.0
# 5192         0.0          0.00                         0.0
# 5193         0.0          0.00                         0.0
# 5194         0.0          0.00                         0.0
# 5195         0.0          0.00                         0.0
#
#       pct.renter.occupied  median.gross.rent  median.household.income  ...  \
# 0                    9.99             1047.0                  76406.0  ...
# 1                   19.55              909.0                  65313.0  ...
# 2                    3.43             1640.0                  94821.0  ...
# 3                    4.44             1327.0                  81761.0  ...
# 4                    9.83             1247.0                  82847.0  ...
# ...                   ...                ...                      ...  ...
# 5191                 0.00                0.0                      0.0  ...
# 5192                 0.00                0.0                      0.0  ...
# 5193                 0.00                0.0                      0.0  ...
# 5194                 0.00                0.0                      0.0  ...
# 5195                 0.00                NaN                      NaN  ...
#
#       pct.multiple  pct.other  eviction.filings  evictions  eviction.rate  \
# 0             1.80       0.25              11.0        8.0           9.64
# 1             3.69       0.18              19.0       11.0           3.54
# 2             1.34       0.00               8.0        3.0           3.45
# 3             0.53       0.00               5.0        3.0           5.63
# 4             1.62       0.00              13.0        5.0           6.73
# ...            ...        ...               ...        ...            ...
# 5191          0.00       0.00               0.0        0.0           0.00
# 5192          0.00       0.00               0.0        0.0           0.00
# 5193          0.00       0.00               0.0        0.0           0.00
# 5194          0.00       0.00               0.0        0.0           0.00
# 5195          0.00       0.00               0.0        0.0           0.00
#
#       eviction.filing.rate  low.flag  imputed  subbed      state
# 0                    13.25         0        0       0  Minnesota
# 1                     6.11         0        0       0  Minnesota
# 2                     9.20         0        0       0  Minnesota
# 3                     9.38         0        0       0  Minnesota
# 4                    17.49         0        0       0  Minnesota
# ...                    ...       ...      ...     ...        ...
# 5191                  0.00         0        0       0   New York
# 5192                  0.00         0        0       0   New York
# 5193                  0.00         0        0       0   New York
# 5194                  0.00         0        0       0   New York
# 5195                  0.00         0        0       0   New York
#
# [250517 rows x 28 columns]

# %%
tracts_df.to_csv('tracts_annual')

# %%
tract_groupby = tracts_df.groupby(['name', 'state'], as_index=False).mean()

# %%
null_groupby = tract_groupby[tract_groupby['eviction.rate'].isna()]

for index, row in null_groupby.iterrows():
        tract_groupby.drop(index, inplace=True)
        
tract_groupby.drop(['low.flag', 'imputed', 'subbed'], axis=1, inplace=True)

tract_groupby.drop(tract_groupby[tract_groupby['population'] == 0].index, inplace=True)

tract_groupby.dropna(inplace=True)

# %%
tract_groupby
# Out:
#                         name           state         GEOID         year  \
# 0      1.01_Ashtabula County            Ohio  3.900700e+10  2009.666667
# 1         1.01_Brazos County           Texas  4.804100e+10  2005.333333
# 2          1.01_Cache County            Utah  4.900500e+10  2014.500000
# 3          1.01_Clark County          Nevada  3.200300e+10  2013.000000
# 4         1.01_Durham County  North Carolina  3.706300e+10  2011.100000
# ...                      ...             ...           ...          ...
# 37607     990.0_Kings County        New York  3.604710e+10  2005.000000
# 37741     992.0_Kings County        New York  3.604710e+10  2005.000000
# 37743     994.0_Kings County        New York  3.604710e+10  2005.000000
# 37744     996.0_Kings County        New York  3.604710e+10  2005.000000
# 37751     998.0_Kings County        New York  3.604710e+10  2005.000000
#
#         population  poverty.rate  renter.occupied.households  \
# 0      4237.666667     15.416667                  457.777778
# 1      5763.093333     10.490000                  731.666667
# 2      4872.000000      6.680000                  285.000000
# 3      6757.000000     11.760000                  484.666667
# 4      2907.503000     23.682000                  492.200000
# ...            ...           ...                         ...
# 37607  1492.333333     11.026667                  209.000000
# 37741  1593.666667      6.013333                  253.000000
# 37743  2106.666667      6.590000                  295.000000
# 37744  3949.000000      6.526667                  564.666667
# 37751  3383.333333     13.096667                  658.000000
#
#        pct.renter.occupied  median.gross.rent  median.household.income  ...  \
# 0                30.570000         369.000000             31828.333333  ...
# 1                24.216667         802.666667             55900.000000  ...
# 2                15.230000         673.000000             52075.000000  ...
# 3                26.170000        1189.000000             46843.000000  ...
# 4                43.092000         765.200000             37424.397000  ...
# ...                    ...                ...                      ...  ...
# 37607            42.196667         983.333333             53631.666667  ...
# 37741            42.733333        1092.333333             62094.666667  ...
# 37743            49.140000        1246.666667             71813.666667  ...
# 37744            46.363333        1141.000000             60286.333333  ...
# 37751            50.996667        1133.666667             48684.000000  ...
#
#        pct.hispanic  pct.am.ind  pct.asian  pct.nh.pi  pct.multiple  \
# 0          4.103333    0.256667   0.256667       0.00      1.403333
# 1         14.703333    0.076667   0.180000       0.00      0.826667
# 2          5.850000    0.120000   0.080000       0.02      0.490000
# 3         63.400000    0.380000   3.180000       2.47      1.260000
# 4         20.623000    0.006000   0.117000       0.00      3.686000
# ...             ...         ...        ...        ...           ...
# 37607      8.716667    0.023333   5.036667       0.00      1.436667
# 37741      5.146667    0.000000   2.823333       0.00      1.353333
# 37743     10.613333    0.120000   0.690000       0.00      1.553333
# 37744      4.250000    0.016667   0.680000       0.00      0.463333
# 37751      5.366667    0.026667   0.820000       0.01      0.590000
#
#        pct.other  eviction.filings  evictions  eviction.rate  \
# 0       0.000000         17.666667   7.666667       1.628889
# 1       0.026667         21.000000   8.000000       1.080000
# 2       0.000000          4.000000   3.000000       1.050000
# 3       0.000000         39.333333  23.666667       4.876667
# 4       0.029000        173.000000  37.900000       7.874000
# ...          ...               ...        ...            ...
# 37607   0.260000         15.666667   6.333333       3.030000
# 37741   0.126667         11.000000   5.333333       2.106667
# 37743   0.053333         32.333333  13.666667       4.620000
# 37744   0.576667         25.333333   9.333333       1.650000
# 37751   0.213333         28.333333  11.666667       1.773333
#
#        eviction.filing.rate
# 0                  3.858889
# 1                  2.853333
# 2                  1.395000
# 3                  8.103333
# 4                 35.982000
# ...                     ...
# 37607              7.500000
# 37741              4.346667
# 37743             10.950000
# 37744              4.486667
# 37751              4.306667
#
# [36110 rows x 24 columns]

# %%
tract_groupby.to_csv('cleaned_tracts.csv')

# %%
gender_df = pd.read_csv('./data/dataframes/all_gender')

# %%
gender_df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
gender_df = gender_df.groupby(by='GEO_ID', as_index=False).median()

# %%
gender_df.rename(columns={'GEO_ID': 'GEOID'}, inplace=True)

# %%
merged = pd.merge(tract_groupby, gender_df, on='GEOID')

# %%
merged.drop(['year_x', 'year_y'], axis=1, inplace=True)

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36068 entries, 0 to 36067
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   name                        36068 non-null  object
#  1   state                       36068 non-null  object
#  2   GEOID                       36068 non-null  float64
#  3   population                  36068 non-null  float64
#  4   poverty.rate                36068 non-null  float64
#  5   renter.occupied.households  36068 non-null  float64
#  6   pct.renter.occupied         36068 non-null  float64
#  7   median.gross.rent           36068 non-null  float64
#  8   median.household.income     36068 non-null  float64
#  9   median.property.value       36068 non-null  float64
#  10  rent.burden                 36068 non-null  float64
#  11  pct.white                   36068 non-null  float64
#  12  pct.af.am                   36068 non-null  float64
#  13  pct.hispanic                36068 non-null  float64
#  14  pct.am.ind                  36068 non-null  float64
#  15  pct.asian                   36068 non-null  float64
#  16  pct.nh.pi                   36068 non-null  float64
#  17  pct.multiple                36068 non-null  float64
#  18  pct.other                   36068 non-null  float64
#  19  eviction.filings            36068 non-null  float64
#  20  evictions                   36068 non-null  float64
#  21  eviction.rate               36068 non-null  float64
#  22  eviction.filing.rate        36068 non-null  float64
#  23  male                        36068 non-null  float64
#  24  female                      36068 non-null  float64
# dtypes: float64(23), object(2)
# memory usage: 7.2+ MB

# %%
merged.to_csv('./data/dataframes/final_tracts.csv')
