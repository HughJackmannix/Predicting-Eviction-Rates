# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
import scipy.stats as stats
warnings.filterwarnings('ignore')

# %%
tracts_df = pd.read_csv('./data/dataframes/final_tracts.csv')

# %%
fig, ax = plt.subplots(figsize=(40, 10))
ax=sns.countplot('state', data=tracts_df)

# %%
tracts_df.state.value_counts()
# Out:
# Texas             3779
# Pennsylvania      3197
# Florida           3156
# Ohio              2907
# North Carolina    2061
# Illinois          1482
# Wisconsin         1392
# Missouri          1390
# Arizona           1295
# New York          1196
# Massachusetts     1196
# Alabama           1173
# Virginia          1156
# Georgia           1150
# Washington        1138
# Colorado           999
# Iowa               801
# Minnesota          748
# Oregon             715
# Kentucky           715
# Michigan           669
# Nevada             517
# Nebraska           469
# Utah               448
# South Carolina     438
# Connecticut        433
# New Mexico         367
# Indiana            244
# Rhode Island       224
# Delaware           214
# California         140
# Maine              139
# Kansas              61
# Wyoming             17
# Oklahoma            14
# Louisiana           12
# Montana              6
# Vermont              5
# Tennessee            4
# Hawaii               1
# Name: state, dtype: int64

# %% [markdown]
# **CLEANING**
# - States with a low amount of entries may cause issues with modeling
# - I will drop those belonging to states with < 400 entries (14)

# %%
drop_states = list(tracts_df.state.value_counts().keys()[-14:])

for index, row in tracts_df.iterrows():
    if row.state in drop_states:
        tracts_df.drop(index, inplace=True)

# %% [markdown]
# ## Feature Engineering - Census Regions & Divisions

# %% [markdown]
# **OBSERVATION**
# - Creating a dummy variable for every census tract (<30,000), or every state (26) is very inefficient
# - I will group the states into the 8 regions designated by the Census
#     1. Pacific
#     2. Mountain
#     3. West North Central
#     4. West South Central
#     5. East North Central
#     6. East South Central
#     7. North East
#     8. Mid Atlantic

# %%
region_dict = {'pcf' : ['Oregon', 'Washington'],
'mt' : ['Nevada', 'Utah', 'Arizona', 'Colorado'],
'wnc' : ['Nebraska', 'Minnesota', 'Iowa', 'Missouri'],
'wsc' : ['Texas'],
'enc' : ['Wisconsin', 'Illinois', 'Michigan', 'Ohio'],
'ma' : ['Pennsylvania', 'New York'],
'ne' : ['Massachusetts', 'Connecticut'],
'sa' : ['Virginia', 'Georgia', 'South Carolina', 'Florida', 'North Carolina'],
'esc' : ['Alabama', 'Kentucky']}

state_list = list(tracts_df['state'])
region_list = []

for state in state_list:
    for key, value in region_dict.items():
        if state in value:
            region_list.append(key)
            
tracts_df['region'] = region_list

# %%
sns.countplot('region', data=tracts_df)
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %% [markdown]
# ## National EDA

# %%
tracts_df[tracts_df['eviction.rate'] > 90 ]
# Out:
#        Unnamed: 0                        name        state         GEOID  \
# 8206         8206          163.0_Bronx County     New York  3.600502e+10
# 9124         9124           18.0_Kings County     New York  3.604700e+10
# 13882       13882           24.0_Bronx County     New York  3.600500e+10
# 14853       14853         27.06_Nueces County        Texas  4.835500e+10
# 18463       18463         36.05_Mobile County      Alabama  1.097004e+09
# 23128       23128      5007.0_Hartford County  Connecticut  9.003501e+09
# 25153       25153         58.0_Jackson County     Michigan  2.607501e+10
# 36016       36016  9805.0_Hillsborough County      Florida  1.205798e+10
#
#         population  poverty.rate  renter.occupied.households  \
# 8206    264.750000     25.000000                    1.000000
# 9124   2187.333333      4.166667                    5.000000
# 13882    37.500000      0.000000                    1.000000
# 14853   711.317500      4.597500                    1.000000
# 18463  1371.000000      0.000000                    1.000000
# 23128  1435.727273      0.000000                    0.818182
# 25153  5060.888889      6.755556                    0.333333
# 36016    39.100000      3.377143                    5.428571
#
#        pct.renter.occupied  median.gross.rent  median.household.income  ...  \
# 8206              0.000000           0.000000                 0.000000  ...
# 9124             28.570000         316.666667             28333.333333  ...
# 13882            25.000000           0.000000                 0.000000  ...
# 14853            32.387500         615.000000             55158.250000  ...
# 18463             0.000000           0.000000                 0.000000  ...
# 23128            36.363636           0.000000                 0.000000  ...
# 25153             7.873333          64.260000              2361.660000  ...
# 36016            29.057143         935.000000             49638.333333  ...
#
#        pct.nh.pi  pct.multiple  pct.other  eviction.filings  evictions  \
# 8206       0.000      0.000000   0.000000         15.000000   2.000000
# 9124       0.000      1.880000   0.070000         43.000000   8.666667
# 13882      0.000      0.000000   0.000000         33.250000   1.500000
# 14853      0.015      0.882500   0.067500          2.000000   1.500000
# 18463      0.000      2.525000   0.330000         13.625000   8.875000
# 23128      0.000      2.465455   0.535455          1.545455   1.454545
# 25153      0.000      4.156667   0.044444          0.888889   0.333333
# 36016      0.010      1.398571   0.035714         18.000000   6.000000
#
#        eviction.rate  eviction.filing.rate   male  female  region
# 8206      200.000000           1500.000000  39.50   60.50      ma
# 9124      174.273333            859.273333  95.70    4.30      ma
# 13882     166.667500           4308.332500  72.95   27.05      ma
# 14853     150.000000            200.000000  41.80   58.20     wsc
# 18463     938.541250           1475.000000  39.70   60.30     esc
# 23128     145.454545            154.545455  98.70    1.30      ne
# 25153      95.805556            151.361111  99.90    0.10     enc
# 36016     378.405714           1137.201429   0.00  100.00      sa
#
# [8 rows x 27 columns]

# %%
tracts_df.drop(tracts_df[tracts_df['eviction.rate'] > 90].index, inplace=True)

# %% [markdown]
# **CLEANING**
# - Eviction rates >= 90 are misleading, as these high rates are due to the fact that an eviction has occured in a census tract with a very low amount of renters (<5)
# - I am dropping these values for the sake of extreme outlier removal

# %%
sns.scatterplot('poverty.rate', 'eviction.rate', data=tracts_df)
# Out:
# <AxesSubplot:xlabel='poverty.rate', ylabel='eviction.rate'>

# %%
sns.distplot(tracts_df['poverty.rate'])
# Out:
# <AxesSubplot:xlabel='poverty.rate', ylabel='Density'>

# %% [markdown]
# **OBSERVATION**
# - eviction rate seems to decerease as poverty rate increases, which seems counterintuitive
# - this could be due to the fact that ~80% of the data has a poverty rate below 20%

# %%
sns.scatterplot('poverty.rate', 'eviction.filing.rate', data=tracts_df)
# Out:
# <AxesSubplot:xlabel='poverty.rate', ylabel='eviction.filing.rate'>

# %%
sns.scatterplot('pct.af.am', 'eviction.rate', data=tracts_df)
# Out:
# <AxesSubplot:xlabel='pct.af.am', ylabel='eviction.rate'>

# %%
sns.scatterplot('pct.af.am', 'rent.burden', data=tracts_df)
# Out:
# <AxesSubplot:xlabel='pct.af.am', ylabel='rent.burden'>

# %%
sns.scatterplot('pct.white', 'eviction.rate', data=tracts_df)
# Out:
# <AxesSubplot:xlabel='pct.white', ylabel='eviction.rate'>

# %%
sns.scatterplot('pct.white', 'rent.burden', data=tracts_df)
# Out:
# <AxesSubplot:xlabel='pct.white', ylabel='rent.burden'>

# %%
sns.scatterplot('rent.burden', 'eviction.rate', data=tracts_df)
# Out:
# <AxesSubplot:xlabel='rent.burden', ylabel='eviction.rate'>

# %%
sns.scatterplot('eviction.rate', 'eviction.filing.rate', data=tracts_df)
# Out:
# <AxesSubplot:xlabel='eviction.rate', ylabel='eviction.filing.rate'>

# %% [markdown]
# **OBSERVATION**
# - The relationship between eviction filing rate and eviction rate seems to have the strongest correlation
#     - This is to be expected as there needs to be an eviction filing before an actual eviction takes place

# %% [markdown]
# ## Feature Engineering - Evictions/Filings Ratio

# %% [markdown]
# - This ratio reflects the percentage of the eviction filings that actually resulted in evictions

# %%
tracts_df['ef.ratio'] = (tracts_df['evictions'] / tracts_df['eviction.filings'])*100

# %%
tracts_df.fillna(0, inplace=True)

# %%
tracts_df['ef.ratio']
# Out:
# 0        43.396226
# 1        38.095238
# 2        75.000000
# 3        60.169492
# 4        21.907514
#            ...
# 36063    40.425532
# 36064    48.484848
# 36065    42.268041
# 36066    36.842105
# 36067    41.176471
# Name: ef.ratio, Length: 34612, dtype: float64

# %%
sns.scatterplot('ef.ratio', 'eviction.rate', data=tracts_df)
# Out:
# <AxesSubplot:xlabel='ef.ratio', ylabel='eviction.rate'>

# %%
tracts_df[tracts_df['ef.ratio'] == 100].describe()
# Out:
#          Unnamed: 0         GEOID    population  poverty.rate  \
# count    889.000000  8.890000e+02    889.000000    889.000000
# mean   24261.148481  3.115754e+10   3074.306801     10.494199
# std    11026.984898  1.594822e+10   1661.855209      9.274150
# min       84.000000  1.047957e+09      0.428571      0.000000
# 25%    15563.000000  2.104720e+10   1900.000000      3.905000
# 50%    30012.000000  2.713107e+10   2775.463333      7.950000
# 75%    33166.000000  4.820134e+10   3975.272727     14.340000
# max    36040.000000  5.513146e+10  13074.310000     63.546667
#
#        renter.occupied.households  pct.renter.occupied  median.gross.rent  \
# count                  889.000000           889.000000         889.000000
# mean                   234.399171            21.020414         793.749372
# std                    178.103355            13.421186         502.744348
# min                      0.071429             0.000000           0.000000
# 25%                    110.000000            12.923333         502.000000
# 50%                    190.000000            18.756364         625.600000
# 75%                    307.000000            25.540000         885.000000
# max                   1049.000000           100.000000        3501.000000
#
#        median.household.income  median.property.value  rent.burden  ...  \
# count               889.000000           8.890000e+02   889.000000  ...
# mean              58955.203130           1.873244e+05    25.747014  ...
# std               37618.395502           2.027746e+05     7.715998  ...
# min                   0.000000           0.000000e+00     0.000000  ...
# 25%               36474.000000           7.300000e+04    21.200000  ...
# 50%               46413.000000           1.078999e+05    25.200000  ...
# 75%               66654.500000           2.105500e+05    29.700000  ...
# max              250001.000000           1.291901e+06    50.033333  ...
#
#         pct.nh.pi  pct.multiple   pct.other  eviction.filings   evictions  \
# count  889.000000    889.000000  889.000000        889.000000  889.000000
# mean     0.057051      1.302337    0.091327          2.791781    2.791781
# std      0.341298      1.294083    0.242351          3.489805    3.489805
# min      0.000000      0.000000    0.000000          0.058824    0.058824
# 25%      0.000000      0.442500    0.000000          0.666667    0.666667
# 50%      0.000000      0.986667    0.000000          1.500000    1.500000
# 75%      0.021429      1.701667    0.067500          3.500000    3.500000
# max      9.040000      9.970000    3.280000         30.000000   30.000000
#
#        eviction.rate  eviction.filing.rate        male      female  ef.ratio
# count     889.000000            889.000000  889.000000  889.000000     889.0
# mean        1.593615              1.593615   50.654274   49.345726     100.0
# std         2.381739              2.381739    6.452154    6.452154       0.0
# min         0.030000              0.030000    2.300000    0.000000     100.0
# 25%         0.424286              0.424286   48.200000   48.400000     100.0
# 50%         0.960000              0.960000   49.900000   50.100000     100.0
# 75%         1.820000              1.820000   51.600000   51.800000     100.0
# max        25.000000             25.000000  100.000000   97.700000     100.0
#
# [8 rows x 25 columns]

# %%
tracts_df[(tracts_df['ef.ratio'] == 100) & (tracts_df['evictions'] < 10)]
# Out:
#        Unnamed: 0                       name         state         GEOID  \
# 84             84           1.0_Alger County      Michigan  2.600300e+10
# 119           119          1.0_Eureka County        Nevada  3.201100e+10
# 133           133           1.0_Henry County          Ohio  3.906900e+10
# 142           142        1.0_Keweenaw County      Michigan  2.608300e+10
# 160           160         1.0_Madison County         Texas  4.831300e+10
# ...           ...                        ...           ...           ...
# 36025       36025  9810.01_Cumberland County  Pennsylvania  4.204198e+10
# 36026       36026    9810.0_Allegheny County  Pennsylvania  4.200398e+10
# 36031       36031    9818.0_Allegheny County  Pennsylvania  4.200398e+10
# 36036       36036    9832.0_Lancaster County      Nebraska  3.110998e+10
# 36040       36040      9883.0_Jackson County      Missouri  2.909599e+10
#
#         population  poverty.rate  renter.occupied.households  \
# 84     3934.000000     10.100000                  439.500000
# 119    1669.000000      8.593333                  247.333333
# 133    4722.000000      4.510000                  273.000000
# 142    2169.500000     10.985000                  105.000000
# 160    5069.000000      5.390000                  108.000000
# ...            ...           ...                         ...
# 36025  3299.453333     13.888333                    6.000000
# 36026    61.365714     20.337143                   17.714286
# 36031   569.321429     31.910000                   41.000000
# 36036   107.785714      0.000000                    1.214286
# 36040   167.028462      0.940000                    1.846154
#
#        pct.renter.occupied  median.gross.rent  median.household.income  ...  \
# 84               19.230000         579.000000             36577.000000  ...
# 119              27.291667         634.833333             54356.166667  ...
# 133              10.330000         733.000000             67965.000000  ...
# 142              10.460000         449.500000             40011.000000  ...
# 160              25.430000         780.000000             45372.000000  ...
# ...                    ...                ...                      ...  ...
# 36025            45.493333         550.500000             34132.333333  ...
# 36026            48.450000         457.000000             24000.142857  ...
# 36031            33.552857         451.627143             23727.431429  ...
# 36036            17.857143           0.000000                 0.000000  ...
# 36040             4.283077        1006.608571             89740.145000  ...
#
#        pct.multiple  pct.other  eviction.filings  evictions  eviction.rate  \
# 84         5.030000   0.000000          7.000000   7.000000       1.595000
# 119        1.228333   0.008333          0.166667   0.166667       0.095000
# 133        0.490000   0.150000          3.000000   3.000000       1.100000
# 142        0.420000   0.000000          0.500000   0.500000       0.485000
# 160        4.710000   0.000000          1.500000   1.500000       1.375000
# ...             ...        ...               ...        ...            ...
# 36025      0.500000   0.058333          0.166667   0.166667       3.333333
# 36026      2.124286   0.135714          0.714286   0.714286       5.337143
# 36031      2.584286   0.085714          0.142857   0.142857       0.358571
# 36036      1.622857   0.000000          0.142857   0.142857      13.095000
# 36040      0.874615   0.020000          0.076923   0.076923       2.286923
#
#        eviction.filing.rate  male  female  region  ef.ratio
# 84                 1.595000  50.3    49.7     enc     100.0
# 119                0.095000  52.1    47.9      mt     100.0
# 133                1.100000  50.0    50.0     enc     100.0
# 142                0.485000  52.3    47.7     enc     100.0
# 160                1.375000  86.4    13.6     wsc     100.0
# ...                     ...   ...     ...     ...       ...
# 36025              3.333333  99.8     0.2      ma     100.0
# 36026              5.337143  50.0    50.0      ma     100.0
# 36031              0.358571  68.6    31.4      ma     100.0
# 36036             13.095000  95.3     4.7     wnc     100.0
# 36040              2.286923  43.2    56.8     wnc     100.0
#
# [839 rows x 28 columns]

# %% [markdown]
# **OBSERVATION**
# - As the % of evictions by filings increases, so does eviction rate
# - % of evictions by filings seems to platue when eviction rate is ~20% (with occasional outliers)
# - ratios of 100% appear to be occuring with low evictions ( 3% of the 100% ratios are of 10 evicitons and up)

# %% [markdown]
# # Majority Race T-test

# %% [markdown]
# Exploring if the eviction rate of a census tract with a majority (>50.4) of a particular race has a significant different between census tracts in which said race is a minority (<=50.4)

# %%
from scipy.stats import ttest_ind

# %%
maj_white = tracts_df[tracts_df['pct.white'] > 50.4]


min_white = tracts_df[tracts_df['pct.white'] <= 50.4]

# %%
white_ttest = ttest_ind(maj_white['eviction.rate'], min_white['eviction.rate'])

# %%
white_ttest
# Out:
# Ttest_indResult(statistic=-59.63449060671495, pvalue=0.0)

# %%
print('Majority White Eviction Rate:', maj_white['eviction.rate'].median())
print('Minority White Eviction Rate:', min_white['eviction.rate'].median())
# Out:
# Majority White Eviction Rate: 2.02
# Minority White Eviction Rate: 4.2

# %%
sns.scatterplot('pct.white', 'eviction.rate', data=maj_white)
# Out:
# <AxesSubplot:xlabel='pct.white', ylabel='eviction.rate'>

# %%
sns.scatterplot('pct.white', 'eviction.rate', data=min_white)

# %% [markdown]
# **OBSERVATION**
# - The eviction rate for majority white census tracts is ~2% lower than census tracts in which white is the minority race
# - p-value of 0.0 indicates a significant difference between the two populations

# %%
maj_afam = tracts_df[tracts_df['pct.af.am'] > 50.4]
min_afam = tracts_df[tracts_df['pct.af.am'] <= 50.4]

afam_ttest = ttest_ind(maj_afam['eviction.rate'], min_afam['eviction.rate'])

print(afam_ttest)
print('Majority Eviction Rate:', maj_afam['eviction.rate'].median())
print('Minority Eviction Rate:', min_afam['eviction.rate'].median())
# Out:
# Ttest_indResult(statistic=54.20309986775818, pvalue=0.0)
# Majority Eviction Rate: 5.6075
# Minority Eviction Rate: 2.2300000000000004

# %%
sns.scatterplot('pct.af.am', 'eviction.rate', data=maj_afam)
# Out:
# <AxesSubplot:xlabel='pct.af.am', ylabel='eviction.rate'>

# %%
sns.scatterplot('pct.af.am', 'eviction.rate', data=min_afam)
# Out:
# <AxesSubplot:xlabel='pct.af.am', ylabel='eviction.rate'>

# %% [markdown]
# **OBSERVATION**
# - The eviction rate for majority aferican american census tracts is >3% higher than census tracts in which aferican american is the minority race
# - p-value of 0.0 indicates a significant difference between the majority and minority populations

# %%
maj_hispanic = tracts_df[tracts_df['pct.hispanic'] > 50.4]
min_hispanic = tracts_df[tracts_df['pct.hispanic'] <= 50.4]

hispanic_ttest = ttest_ind(maj_hispanic['eviction.rate'], min_hispanic['eviction.rate'])

print(hispanic_ttest[1])
print('Majority Eviction Rate:', maj_hispanic['eviction.rate'].median())
print('Minority Eviction Rate:', min_hispanic['eviction.rate'].median())
# Out:
# 1.0681346622092608e-12
# Majority Eviction Rate: 2.94
# Minority Eviction Rate: 2.382307692307692

# %%
sns.scatterplot('pct.hispanic', 'eviction.rate', data=maj_hispanic)
# Out:
# <AxesSubplot:xlabel='pct.hispanic', ylabel='eviction.rate'>

# %%
sns.scatterplot('pct.hispanic', 'eviction.rate', data=min_hispanic)
# Out:
# <AxesSubplot:xlabel='pct.hispanic', ylabel='eviction.rate'>

# %% [markdown]
# **OBSERVATION**
# - The eviction rate for majority hispanic census tracts is ~0.6% higher than census tracts in which hispanic is the minority race
# - miniscule p-value indicates a significant difference between the two populations

# %%
maj_amind = tracts_df[tracts_df['pct.am.ind'] > 50.4]
min_amind = tracts_df[tracts_df['pct.am.ind'] <= 50.4]

amind_ttest = ttest_ind(maj_amind['eviction.rate'], min_amind['eviction.rate'])

print(amind_ttest[1])
print('Majority Eviction Rate:', maj_amind['eviction.rate'].median())
print('Minority Eviction Rate:', min_amind['eviction.rate'].median())
# Out:
# 2.6002969388137e-09
# Majority Eviction Rate: 0.19166666666666665
# Minority Eviction Rate: 2.4250000000000003

# %% [markdown]
# **OBSERVATION**
# - Eviction rate increases when native american population is the minority race

# %%
print('Majority Eviction Rate:', maj_amind['eviction.rate'].mean())
print('Minority Eviction Rate:', min_amind['eviction.rate'].mean())
# Out:
# Majority Eviction Rate: 0.8431973951973951
# Minority Eviction Rate: 3.5051934919654326

# %%
print(maj_amind.shape[0])
print(min_amind.shape[0])
# Out:
# 63
# 34549

# %%
maj_asian = tracts_df[tracts_df['pct.asian'] > 50.4]
min_asian = tracts_df[tracts_df['pct.asian'] <= 50.4]

asian_ttest = ttest_ind(maj_asian['eviction.rate'], min_asian['eviction.rate'])

print(asian_ttest[1])
print('Majority Eviction Rate:', maj_asian['eviction.rate'].median())
print('Minority Eviction Rate:', min_asian['eviction.rate'].median())
# Out:
# 0.0001705529250267641
# Majority Eviction Rate: 0.72
# Minority Eviction Rate: 2.4214285714285717

# %% [markdown]
# **OBSERVATION**
# - The eviction rate for majority asian census tracts is ~2% lower than census tracts in which asian is the minority race
# - p-value <0.05 indicates a significant difference between the two populations

# %%
maj_nhpi = tracts_df[tracts_df['pct.nh.pi'] > 50.4]
min_nhpi = tracts_df[tracts_df['pct.nh.pi'] <= 50.4]

nhpi_ttest = ttest_ind(maj_nhpi['eviction.rate'], min_nhpi['eviction.rate'])

print(nhpi_ttest[1])
print('Majority Eviction Rate:', maj_nhpi['eviction.rate'].median())
print('Minority Eviction Rate:', min_nhpi['eviction.rate'].median())
# Out:
# nan
# Majority Eviction Rate: nan
# Minority Eviction Rate: 2.42

# %%
maj_mult = tracts_df[tracts_df['pct.multiple'] > 50.4]
min_mult = tracts_df[tracts_df['pct.multiple'] <= 50.4]

mult_ttest = ttest_ind(maj_mult['eviction.rate'], min_mult['eviction.rate'])

print(mult_ttest[1])
print('Majority Eviction Rate:', maj_mult['eviction.rate'].median())
print('Minority Eviction Rate:', min_mult['eviction.rate'].median())
# Out:
# nan
# Majority Eviction Rate: nan
# Minority Eviction Rate: 2.42

# %%
maj_other = tracts_df[tracts_df['pct.other'] > 50.4]
min_other = tracts_df[tracts_df['pct.other'] <= 50.4]

other_ttest = ttest_ind(maj_other['eviction.rate'], min_other['eviction.rate'])

print(other_ttest[1])
print('Majority Eviction Rate:', maj_other['eviction.rate'].median())
print('Minority Eviction Rate:', min_other['eviction.rate'].median())
# Out:
# nan
# Majority Eviction Rate: nan
# Minority Eviction Rate: 2.42

# %% [markdown]
# **OBSERVATION**
# - There are no entries of census tracts in which native hawaiins/pacific islanders, multiple (races), or other (race) have a majority

# %% [markdown]
# # Majority Gender T-test

# %%
maj_male = tracts_df[tracts_df['male'] > 50.4]
min_male = tracts_df[tracts_df['male'] <= 50.4]

male_ttest = ttest_ind(maj_male['eviction.rate'], min_male['eviction.rate'])

print(male_ttest[1])
print('Majority Eviction Rate:', maj_male['eviction.rate'].median())
print('Minority Eviction Rate:', min_male['eviction.rate'].median())
# Out:
# 1.91760880216826e-08
# Majority Eviction Rate: 2.272678571428571
# Minority Eviction Rate: 2.48

# %%
sns.scatterplot('male', 'eviction.rate', data=maj_male)
# Out:
# <AxesSubplot:xlabel='male', ylabel='eviction.rate'>

# %%
sns.scatterplot('male', 'eviction.rate', data=min_male)
# Out:
# <AxesSubplot:xlabel='male', ylabel='eviction.rate'>

# %%
sns.scatterplot('male', 'eviction.rate', data=tracts_df)
# Out:
# <AxesSubplot:xlabel='male', ylabel='eviction.rate'>

# %%
maj_female = tracts_df[tracts_df['female'] > 50.4]
min_female = tracts_df[tracts_df['female'] <= 50.4]

female_ttest = ttest_ind(maj_female['eviction.rate'], min_female['eviction.rate'])

print(female_ttest[1])
print('Majority Eviction Rate:', maj_female['eviction.rate'].median())
print('Minority Eviction Rate:', min_female['eviction.rate'].median())
# Out:
# 6.254226495766264e-17
# Majority Eviction Rate: 2.5442727272727277
# Minority Eviction Rate: 2.25

# %%
sns.scatterplot('female', 'eviction.rate', data=tracts_df)
# Out:
# <AxesSubplot:xlabel='female', ylabel='eviction.rate'>

# %% [markdown]
# **OBSERVATION**
# - Eviction rates in majority female census tracts are 0.3% higher than male majority census tracts
# - p-values all lower than 0.05

# %% [markdown]
# ## State Level EDA

# %%
state_df.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-666c69a82941> in <module>
# ----> 1 state_df.reset_index(inplace=True)
#
# NameError: name 'state_df' is not defined

# %%
state_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-2777adfc1c44> in <module>
# ----> 1 state_df
#
# NameError: name 'state_df' is not defined

# %%
fig, ax = plt.subplots(figsize=(20,10))

ax = sns.barplot('eviction.rate', 'state', data=state_df.sort_values('eviction.rate', ascending=False))

# %%
fig, ax = plt.subplots(figsize=(20,10))

ax = sns.barplot('eviction.filing.rate', 'state', data=state_df.sort_values('eviction.filing.rate', ascending=False))

# %%
fig, ax = plt.subplots(figsize=(20,10))

ax = sns.barplot('renter.occupied.households', 'state', data=state_df.sort_values('renter.occupied.households',ascending=False))

# %%
fig, ax = plt.subplots(figsize=(20,10))

ax = sns.barplot('poverty.rate', 'state', data=state_df.sort_values('poverty.rate', ascending=False))

# %%
fig, ax = plt.subplots(figsize=(20,10))

ax = sns.barplot('rent.burden', 'state', data=state_df.sort_values('rent.burden', ascending=False))

# %% [markdown]
# # Modeling

# %% [markdown]
# ### Checking Assumptions for Linear Regression

# %% [markdown]
# #### 1.  Multicullinearity

# %%
plt.figure(figsize=(18,10))
sns.heatmap(data = tracts_df.corr(), center=0, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **OBSERVATION**
# 1. Correlations .75 and above:
#     - eviction.filings vs evitions
#     - eviction.filings vs eviction.filings.rate
#     - male vs female
# 2. Dropping evictions and eviction.filing.rate as their values are reflected in eviction.filings
#     - dropping renter.occupied.households (despite being slightly lower than 0.75) due to value being reflected in pct.renter.occupied
#     - dropping pct.white (despite being slightly higher than -0.75) due to its value being closely related to pct.af.am
# 3. Dropping male column as insight will be inferrable based on findings of female variable

# %%
model_df = tracts_df.drop(['evictions', 'eviction.filing.rate', 'renter.occupied.households', 
                           'Unnamed: 0', 'name', 'GEOID', 'male', 'white', 'state'], axis=1)

# %%
plt.figure(figsize=(18,10))
sns.heatmap(data = model_df.corr(), center=0, annot=True)
# Out:
# <AxesSubplot:>

# %%
region_dummies = pd.get_dummies(tracts_df['region'], drop_first=True)
model_df = pd.concat([model_df, region_dummies], axis=1)
model_df.drop('region', axis=1, inplace=True)

# %%
model_df.columns = model_df.columns.str.replace(".","_")

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from statsmodels.formula.api import ols
import statsmodels.api as sm

# %%
def linreg_model(df, target):
    outcome = target
    predictors = df.drop(target, axis=1)
    predictor_variables = "+".join(predictors.columns)
    formula = outcome + '~' + predictor_variables
    model_baseline = ols(formula=formula, data=df).fit()
     
    X = model_df.drop("eviction_rate", axis = 1)
    y = model_df['eviction_rate']

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 25)

    baseline_linreg = LinearRegression()

    baseline_linreg.fit(X_train, y_train)

    y_pred = baseline_linreg.predict(X_test)

    residuals = y_pred - y_test
    
    
    mse_train = mean_squared_error(y_train, baseline_linreg.predict(X_train))
    mse_test = mean_squared_error(y_test, y_pred)

    residuals = model_baseline.resid
    fig = sm.graphics.qqplot(residuals, dist=stats.norm, line='45', fit=True)

    print("Train RMSE:", np.sqrt(mse_train))
    print("Test RMSE:", np.sqrt(mse_test))
    print('Test Difference:', np.sqrt(mse_test) - np.sqrt(mse_train))
    fig.show()
    
    return model_baseline.summary()

# %%
linreg_model(model_df, 'eviction_rate')
# Out:
# Train RMSE: 2.6550435000475097
# Test RMSE: 2.5366814417724397
# Test Difference: -0.11836205827506996
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          eviction_rate   R-squared:                       0.452
# Model:                            OLS   Adj. R-squared:                  0.452
# Method:                 Least Squares   F-statistic:                     1098.
# Date:                Fri, 27 Aug 2021   Prob (F-statistic):               0.00
# Time:                        15:41:53   Log-Likelihood:                -82503.
# No. Observations:               34612   AIC:                         1.651e+05
# Df Residuals:                   34585   BIC:                         1.653e+05
# Df Model:                          26
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  11.5120      1.141     10.086      0.000       9.275      13.749
# population                 -0.0002   8.18e-06    -21.580      0.000      -0.000      -0.000
# poverty_rate                0.0313      0.002     13.564      0.000       0.027       0.036
# pct_renter_occupied        -0.0320      0.001    -28.712      0.000      -0.034      -0.030
# median_gross_rent           0.0001   7.51e-05      1.724      0.085   -1.77e-05       0.000
# median_household_income  1.678e-05   1.38e-06     12.178      0.000    1.41e-05    1.95e-05
# median_property_value   -5.435e-06    1.9e-07    -28.549      0.000   -5.81e-06   -5.06e-06
# rent_burden                 0.0263      0.003     10.127      0.000       0.021       0.031
# pct_white                  -0.0955      0.012     -8.303      0.000      -0.118      -0.073
# pct_af_am                  -0.0642      0.012     -5.561      0.000      -0.087      -0.042
# pct_hispanic               -0.0878      0.012     -7.606      0.000      -0.110      -0.065
# pct_am_ind                 -0.1327      0.012    -11.001      0.000      -0.156      -0.109
# pct_asian                  -0.0866      0.012     -7.233      0.000      -0.110      -0.063
# pct_nh_pi                  -0.2093      0.041     -5.126      0.000      -0.289      -0.129
# pct_multiple                0.1587      0.016      9.624      0.000       0.126       0.191
# pct_other                  -0.0725      0.032     -2.275      0.023      -0.135      -0.010
# eviction_filings            0.0228      0.000    106.731      0.000       0.022       0.023
# female                     -0.0259      0.003     -7.447      0.000      -0.033      -0.019
# ef_ratio                    0.0272      0.001     31.890      0.000       0.026       0.029
# esc                        -1.3095      0.070    -18.723      0.000      -1.447      -1.172
# ma                         -0.1768      0.053     -3.322      0.001      -0.281      -0.072
# mt                          1.3076      0.061     21.379      0.000       1.188       1.427
# ne                         -0.2016      0.079     -2.563      0.010      -0.356      -0.047
# pcf                        -0.8512      0.075    -11.288      0.000      -0.999      -0.703
# sa                          0.4485      0.047      9.604      0.000       0.357       0.540
# wnc                        -0.4917      0.056     -8.716      0.000      -0.602      -0.381
# wsc                        -0.0750      0.061     -1.232      0.218      -0.194       0.044
# ==============================================================================
# Omnibus:                    27927.393   Durbin-Watson:                   1.778
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3426047.235
# Skew:                           3.202   Prob(JB):                         0.00
# Kurtosis:                      51.318   Cond. No.                     1.87e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.87e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # Random Forrest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn import tree
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import explained_variance_score
from sklearn.metrics import max_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

import math
import statistics as stat

# %%
def rf_report(classifier):
    
    # calculating variance
    var_train = explained_variance_score(y_train, classifier.predict(X_train_scaled))
    var_test = explained_variance_score(y_test, classifier.predict(X_test_scaled))
    
    #calculating max error
    max_error_train = max_error(y_train, classifier.predict(X_train_scaled))
    max_error_test = max_error(y_test, classifier.predict(X_test_scaled))
    
    #calculating RMSE
    rmse_train = math.sqrt(mean_squared_error(y_train, classifier.predict(X_train_scaled)))
    rmse_test = math.sqrt(mean_squared_error(y_test, classifier.predict(X_test_scaled)))
    
    #calculating R2
    r_sq_train = r2_score(y_train, classifier.predict(X_train_scaled))
    r_sq_test = r2_score(y_test, classifier.predict(X_test_scaled))
 

    #printing scores
    print('Variance --------------------------------------------')
    print('Train Variance: {}'.format(var_train))
    print('Test Variance: {}'.format(var_test))
    print('Max Error --------------------------------------------')
    print('Max Error Train: {}'.format(max_error_train))
    print('Max Error Test: {}'.format(max_error_test))
    print('RMSE --------------------------------------------')
    print('Train RMSE: {}'.format(rmse_train))
    print('Test RMSE: {}'.format(rmse_test))
    print('R2 --------------------------------------------')
    print('R2 Train: {}'.format(r_sq_train))
    print('R2 Test: {}'.format(r_sq_test))

# %% [markdown]
# ### Random Forest Baseline

# %% [markdown]
# 1. Continuing to use the same features used in the linear regression model to better compare performance

# %%
X = model_df.drop("eviction_rate", axis = 1)
y = model_df['eviction_rate']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 25)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
forest_base = RandomForestRegressor()
forest_base_model = forest_base.fit(X_train_scaled, y_train)

# %%
rf_report(forest_base)
# Out:
# Variance --------------------------------------------
# Train Variance: 0.973664096070169
# Test Variance: 0.8136979394300534
# Max Error --------------------------------------------
# Max Error Train: 20.653378095238104
# Max Error Test: 49.98756269980021
# RMSE --------------------------------------------
# Train RMSE: 0.5806186494035452
# Test RMSE: 1.4889068803063623
# R2 --------------------------------------------
# R2 Train: 0.9736598477295011
# R2 Test: 0.8135511488588396

# %%
max_depth = []
for classifier in forest_base_model:
    max_depth.append(classifier.tree_.max_depth)

# %%
stat.median(max_depth)
# Out:
# 32.0

# %% [markdown]
# **OBSERVATION**
# - While the training model is nearly completely learning the training data, it still achieves a good R2 on the testing data
# - Overfitting occuring around depth of 32

# %%
def plot_feature_importances_base(model):
    n_features = X_train.shape[1]
    plt.figure(figsize=(20,20))
    plt.barh(range(n_features), model.feature_importances_, align='center') 
    plt.yticks(np.arange(n_features), X_train.columns.values) 
    plt.xlabel('Feature importance')
    plt.ylabel('Feature')

# %%
plot_feature_importances_base(forest_base_model)

# %% [markdown]
# **OBSERVATION**
# - As expected, the random foreset model puts much more importance on the continuous features
# - Eviction filings are by the the most important feature, followed by pct_renter_occupied

# %% [markdown]
# ## Random Forest v2

# %%
forest_v2 = RandomForestRegressor()

param_grid = {'max_depth': [20, 25, 30],
             'min_samples_split': [10, 15, 20],
             'min_samples_leaf': [20, 30, 40]}

forest_v2_model = GridSearchCV(estimator = forest_v2, param_grid=param_grid, cv=3)
forest_v2_model.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [20, 25, 30],
#                          'min_samples_leaf': [20, 30, 40],
#                          'min_samples_split': [10, 15, 20]})

# %%
def report_grid(model):
    params = print(model.best_params_)
    print(params)
    return rf_report(model)

def plot_feature_importances(model):
    n_features = X_train.shape[1]
    plt.figure(figsize=(20,20))
    plt.barh(range(n_features), model.best_estimator_.feature_importances_, align='center') 
    plt.yticks(np.arange(n_features), X_train.columns.values) 
    plt.xlabel('Feature importance')
    plt.ylabel('Feature')

# %%
report_grid(forest_v2_model)
# Out:
# {'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 10}
# None
# Variance --------------------------------------------
# Train Variance: 0.822059738437825
# Test Variance: 0.7666962553131623
# Max Error --------------------------------------------
# Max Error Train: 48.7081969868541
# Max Error Test: 57.83455475243008
# RMSE --------------------------------------------
# Train RMSE: 1.5091072534533305
# Test RMSE: 1.6656329469506477
# R2 --------------------------------------------
# R2 Train: 0.8220587930928802
# R2 Test: 0.7666631967799029

# %% [markdown]
# **OBSERVATION**
# - test R2 is lower by ~3% compared to baseline
# - RMSE is higher by 0.1
# - slighly worse performance after parameter optimization via gridsearch could be due to

# %%
plot_feature_importances(forest_v2_model)

# %% [markdown]
# ## XGBoost

# %%
import xgboost
from xgboost import XGBRegressor

# %%
xgb_base = XGBRegressor()
xgb_base_model = xgb_base.fit(X_train_scaled, y_train)

# %%
rf_report(xgb_base)
# Out:
# Variance --------------------------------------------
# Train Variance: 0.9652099199859977
# Test Variance: 0.8197650136441168
# Max Error --------------------------------------------
# Max Error Train: 8.102600173950197
# Max Error Test: 55.35711641311646
# RMSE --------------------------------------------
# Train RMSE: 0.6672822272382062
# Test RMSE: 1.4638864816088353
# R2 --------------------------------------------
# R2 Train: 0.9652099194421531
# R2 Test: 0.8197648722982496

# %%
plot_feature_importances_base(xgb_base)

# %% [markdown]
# **OBSERVATION**
# - This model is performing on par with the decision random forest basemodel
# - XGBoost is relying more on the cateogorical (region) features than the randomforest model
#     - most important regions are ma(mid atlantic) and mt (mountain)

# %%
xgb_v2 = XGBRegressor()

param_grid = {
    'learning_rate' : [0.1, 0.2],
    'max_depth': [4, 6, 8],
    'min_child_weight': [1, 2],
    'sub_sample': [0.5, 0.7],
    
}

xgb_v2_model = GridSearchCV(estimator = xgb_v2, param_grid=param_grid, cv=3)
xgb_v2_model.fit(X_train_scaled, y_train)
# Out:
# [16:04:26] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:04:29] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:04:31] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:04:33] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:04:35] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:04:38] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:04:40] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:04:42] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:04:45] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:04:48] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:04:50] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:04:52] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:04:54] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:04:59] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:05:03] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:05:09] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:05:13] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:05:17] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:05:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:05:25] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:05:28] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:05:31] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [16:05:35] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:05:39] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:05:42] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:05:45] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:05:50] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:05:54] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:05:59] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:06:04] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:06:07] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:06:11] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:06:14] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:06:18] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:06:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:06:24] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:06:28] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:06:29] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:06:31] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:06:33] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:06:34] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:06:36] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:06:38] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:06:39] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [16:06:41] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:06:43] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:06:44] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:06:46] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:06:48] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:06:50] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:06:53] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:06:55] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:06:58] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:07:00] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:07:03] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:07:05] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:07:08] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:07:10] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:07:13] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:07:15] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:07:18] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:07:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:07:24] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:07:28] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:07:31] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:07:34] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [16:07:37] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:07:41] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:07:44] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:07:47] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:07:51] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:07:54] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:07:57] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# GridSearchCV(cv=3,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, gamma=None,
#                                     gpu_id=None, importance_type='gain',
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_delta_step=None,
#                                     max_depth=None, min_child_weight=None,
#                                     missing=nan, monotone_constraints=None,
#                                     n_estimators=100, n_jobs=None,
#                                     num_parallel_tree=None, random_state=None,
#                                     reg_alpha=None, reg_lambda=None,
#                                     scale_pos_weight=None, subsample=None,
#                                     tree_method=None, validate_parameters=None,
#                                     verbosity=None),
#              param_grid={'learning_rate': [0.1, 0.2], 'max_depth': [4, 6, 8],
#                          'min_child_weight': [1, 2], 'sub_sample': [0.5, 0.7]})

# %%
report_grid(xgb_v2_model)
# Out:
# {'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 1, 'sub_sample': 0.5}
# None
# Variance --------------------------------------------
# Train Variance: 0.9483184468562175
# Test Variance: 0.827371923129873
# Max Error --------------------------------------------
# Max Error Train: 12.196526845296233
# Max Error Test: 50.35635490417481
# RMSE --------------------------------------------
# Train RMSE: 0.8132982968132566
# Test RMSE: 1.4326654508341647
# R2 --------------------------------------------
# R2 Train: 0.94831838880905
# R2 Test: 0.8273708175466017

# %%
plot_feature_importances(xgb_v2_model)

# %% [markdown]
# **OBSERVATION**
# - Optimization has improved R2 by 1%, and lowered RMSE by 0.04
# - Placing much more importance on MT region than MA region compared to basemodel

# %%
mt = tracts_df[tracts_df['region'] == 'mt']

# %%
sns.scatterplot('eviction.filings', 'eviction.rate', data=mt)
# Out:
# <AxesSubplot:xlabel='eviction.filings', ylabel='eviction.rate'>

# %%
sns.scatterplot('eviction.filings', 'eviction.rate', data=tracts_df)
# Out:
# <AxesSubplot:xlabel='eviction.filings', ylabel='eviction.rate'>

# %%
tracts_df[(tracts_df['eviction.rate'] > 8) & (tracts_df['evictions'] < 10)]
# Out:
#        Unnamed: 0                         name           state         GEOID  \
# 532           532  1002.08_Chesterfield County        Virginia  5.104110e+10
# 997           997  1010.11_Chesterfield County        Virginia  5.104110e+10
# 1043         1043         1014.03_Bucks County    Pennsylvania  4.201710e+10
# 1172         1172        102.04_Clinton County        Michigan  2.603701e+10
# 3104         3104         110.02_Dallas County           Texas  4.811301e+10
# ...           ...                          ...             ...           ...
# 35470       35470      9705.03_Cherokee County  South Carolina  4.502197e+10
# 35972       35972          9800.01_Bell County           Texas  4.802798e+10
# 35981       35981       9800.0_Franklin County            Ohio  3.904998e+10
# 36005       36005           9801.0_Wake County  North Carolina  3.718398e+10
# 36036       36036      9832.0_Lancaster County        Nebraska  3.110998e+10
#
#         population  poverty.rate  renter.occupied.households  \
# 532    2642.000000      6.480000                   83.000000
# 997    3206.000000      2.420000                   83.000000
# 1043   6207.434286      3.078571                   84.857143
# 1172   1804.750000      6.190000                   49.500000
# 3104   3047.714286      5.675714                  106.000000
# ...            ...           ...                         ...
# 35470  1265.666667     13.853333                  102.666667
# 35972    77.809286      7.422143                    0.142857
# 35981     0.463846     58.194615                    0.846154
# 36005    25.422500      0.260000                    0.125000
# 36036   107.785714      0.000000                    1.214286
#
#        pct.renter.occupied  median.gross.rent  median.household.income  ...  \
# 532              11.900000        1391.000000             81979.000000  ...
# 997               6.480000        1710.000000             94409.000000  ...
# 1043              2.937143         809.351429             72594.728571  ...
# 1172              7.785000         940.750000             75779.750000  ...
# 3104              8.070000         937.000000             61647.285714  ...
# ...                    ...                ...                      ...  ...
# 35470            18.663333         505.000000             34183.000000  ...
# 35972            49.723571         841.571429             35240.285714  ...
# 35981            68.485385         215.625000              2301.000000  ...
# 36005            71.305000         953.000000             89871.000000  ...
# 36036            17.857143           0.000000                 0.000000  ...
#
#        pct.multiple  pct.other  eviction.filings  evictions  eviction.rate  \
# 532        1.170000   0.530000         10.000000   8.000000       9.640000
# 997        5.490000   0.000000         15.000000   8.000000       9.640000
# 1043       0.314286   0.000000         19.142857   7.142857       8.348571
# 1172       2.018750   0.216250          9.125000   4.875000      10.003750
# 3104       0.278571   0.131429         31.571429   9.857143       9.665714
# ...             ...        ...               ...        ...            ...
# 35470      0.590000   0.023333         15.000000   9.666667       9.456667
# 35972      1.931429   0.089286          0.214286   0.214286      21.428571
# 35981      0.000000   0.000000          0.461538   0.307692      49.762308
# 36005      0.447500   0.092500          0.500000   0.125000      12.500000
# 36036      1.622857   0.000000          0.142857   0.142857      13.095000
#
#        eviction.filing.rate   male  female  region    ef.ratio
# 532               12.050000   48.5    51.5      sa   80.000000
# 997               18.070000   52.7    47.3      sa   53.333333
# 1043              22.478571   45.1    54.9      ma   37.313433
# 1172              18.492500   50.6    49.4     enc   53.424658
# 3104              30.771429   45.4    54.6     wsc   31.221719
# ...                     ...    ...     ...     ...         ...
# 35470             14.623333   49.5    50.5      sa   64.444444
# 35972             21.428571   70.7    29.3     wsc  100.000000
# 35981             66.677692  100.0     0.0     enc   66.666667
# 36005            120.281250  100.0     0.0      sa   25.000000
# 36036             13.095000   95.3     4.7     wnc  100.000000
#
# [150 rows x 28 columns]

# %%
y.describe()
# Out:
# count    34612.000000
# mean         3.500348
# std          3.545686
# min          0.000000
# 25%          1.220000
# 50%          2.420000
# 75%          4.550708
# max         60.700000
# Name: eviction_rate, dtype: float64

# %% [markdown]
# ## MLN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import optimizers
from sklearn import metrics

# %%
base_nn = Sequential()
base_nn.add(Dense(X.shape[1], input_dim=X.shape[1], activation='relu'))
base_nn.add(Dense(1))

earlystopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=15, verbose=2, mode='auto')

base_nn.compile(loss='mean_squared_error', optimizer='adam')
base_nn.fit(X_train_scaled, y_train, validation_split=0.1, callbacks=[earlystopper],
            verbose=2, epochs=500)
# Out:
# Epoch 1/500
# 731/731 - 1s - loss: 10.7277 - val_loss: 6.7285
# Epoch 2/500
# 731/731 - 1s - loss: 6.1880 - val_loss: 4.9140
# Epoch 3/500
# 731/731 - 1s - loss: 4.7753 - val_loss: 3.8288
# Epoch 4/500
# 731/731 - 1s - loss: 4.0389 - val_loss: 3.4206
# Epoch 5/500
# 731/731 - 1s - loss: 3.6936 - val_loss: 3.1187
# Epoch 6/500
# 731/731 - 1s - loss: 3.5093 - val_loss: 3.0208
# Epoch 7/500
# 731/731 - 1s - loss: 3.3877 - val_loss: 2.9142
# Epoch 8/500
# 731/731 - 1s - loss: 3.2742 - val_loss: 2.8195
# Epoch 9/500
# 731/731 - 1s - loss: 3.1906 - val_loss: 2.8492
# Epoch 10/500
# 731/731 - 1s - loss: 3.1323 - val_loss: 2.7666
# Epoch 11/500
# 731/731 - 1s - loss: 3.0603 - val_loss: 2.6270
# Epoch 12/500
# 731/731 - 1s - loss: 3.0221 - val_loss: 2.6405
# Epoch 13/500
# 731/731 - 1s - loss: 2.9640 - val_loss: 2.6202
# Epoch 14/500
# 731/731 - 1s - loss: 2.9197 - val_loss: 2.5844
# Epoch 15/500
# 731/731 - 1s - loss: 2.8845 - val_loss: 2.5535
# Epoch 16/500
# 731/731 - 1s - loss: 2.8385 - val_loss: 2.5373
# Epoch 17/500
# 731/731 - 1s - loss: 2.8077 - val_loss: 2.5964
# Epoch 18/500
# 731/731 - 1s - loss: 2.7722 - val_loss: 2.4776
# Epoch 19/500
# 731/731 - 1s - loss: 2.7441 - val_loss: 2.4562
# Epoch 20/500
# 731/731 - 1s - loss: 2.7238 - val_loss: 2.4819
# Epoch 21/500
# 731/731 - 1s - loss: 2.6990 - val_loss: 2.4501
# Epoch 22/500
# 731/731 - 1s - loss: 2.6690 - val_loss: 2.4798
# Epoch 23/500
# 731/731 - 1s - loss: 2.6574 - val_loss: 2.4730
# Epoch 24/500
# 731/731 - 1s - loss: 2.6435 - val_loss: 2.4100
# Epoch 25/500
# 731/731 - 1s - loss: 2.6179 - val_loss: 2.3737
# Epoch 26/500
# 731/731 - 1s - loss: 2.5978 - val_loss: 2.3750
# Epoch 27/500
# 731/731 - 1s - loss: 2.5888 - val_loss: 2.3913
# Epoch 28/500
# 731/731 - 1s - loss: 2.5632 - val_loss: 2.3910
# Epoch 29/500
# 731/731 - 1s - loss: 2.5598 - val_loss: 2.3542
# Epoch 30/500
# 731/731 - 1s - loss: 2.5368 - val_loss: 2.4063
# Epoch 31/500
# 731/731 - 1s - loss: 2.5204 - val_loss: 2.3628
# Epoch 32/500
# 731/731 - 1s - loss: 2.5139 - val_loss: 2.3360
# Epoch 33/500
# 731/731 - 1s - loss: 2.4982 - val_loss: 2.3238
# Epoch 34/500
# 731/731 - 1s - loss: 2.4821 - val_loss: 2.2979
# Epoch 35/500
# 731/731 - 1s - loss: 2.4835 - val_loss: 2.3060
# Epoch 36/500
# 731/731 - 1s - loss: 2.4631 - val_loss: 2.2797
# Epoch 37/500
# 731/731 - 1s - loss: 2.4492 - val_loss: 2.2991
# Epoch 38/500
# 731/731 - 1s - loss: 2.4381 - val_loss: 2.2561
# Epoch 39/500
# 731/731 - 1s - loss: 2.4416 - val_loss: 2.2674
# Epoch 40/500
# 731/731 - 1s - loss: 2.4299 - val_loss: 2.2431
# Epoch 41/500
# 731/731 - 1s - loss: 2.4064 - val_loss: 2.2353
# Epoch 42/500
# 731/731 - 1s - loss: 2.3976 - val_loss: 2.3784
# Epoch 43/500
# 731/731 - 1s - loss: 2.3959 - val_loss: 2.2390
# Epoch 44/500
# 731/731 - 1s - loss: 2.3917 - val_loss: 2.2275
# Epoch 45/500
# 731/731 - 1s - loss: 2.3816 - val_loss: 2.1850
# Epoch 46/500
# 731/731 - 1s - loss: 2.3688 - val_loss: 2.2113
# Epoch 47/500
# 731/731 - 1s - loss: 2.3643 - val_loss: 2.2103
# Epoch 48/500
# 731/731 - 1s - loss: 2.3606 - val_loss: 2.2092
# Epoch 49/500
# 731/731 - 1s - loss: 2.3507 - val_loss: 2.1778
# Epoch 50/500
# 731/731 - 1s - loss: 2.3399 - val_loss: 2.2119
# Epoch 51/500
# 731/731 - 1s - loss: 2.3262 - val_loss: 2.1608
# Epoch 52/500
# 731/731 - 1s - loss: 2.3282 - val_loss: 2.1736
# Epoch 53/500
# 731/731 - 1s - loss: 2.3195 - val_loss: 2.1456
# Epoch 54/500
# 731/731 - 1s - loss: 2.3147 - val_loss: 2.1640
# Epoch 55/500
# 731/731 - 1s - loss: 2.3088 - val_loss: 2.1200
# Epoch 56/500
# 731/731 - 1s - loss: 2.3000 - val_loss: 2.1364
# Epoch 57/500
# 731/731 - 1s - loss: 2.3049 - val_loss: 2.1209
# Epoch 58/500
# 731/731 - 1s - loss: 2.2900 - val_loss: 2.0901
# Epoch 59/500
# 731/731 - 1s - loss: 2.2844 - val_loss: 2.1709
# Epoch 60/500
# 731/731 - 1s - loss: 2.2828 - val_loss: 2.1273
# Epoch 61/500
# 731/731 - 1s - loss: 2.2715 - val_loss: 2.1781
# Epoch 62/500
# 731/731 - 1s - loss: 2.2638 - val_loss: 2.1883
# Epoch 63/500
# 731/731 - 1s - loss: 2.2696 - val_loss: 2.0912
# Epoch 64/500
# 731/731 - 1s - loss: 2.2505 - val_loss: 2.0880
# Epoch 65/500
# 731/731 - 1s - loss: 2.2566 - val_loss: 2.1266
# Epoch 66/500
# 731/731 - 1s - loss: 2.2444 - val_loss: 2.0934
# Epoch 67/500
# 731/731 - 1s - loss: 2.2459 - val_loss: 2.0792
# Epoch 68/500
# 731/731 - 1s - loss: 2.2363 - val_loss: 2.1111
# Epoch 69/500
# 731/731 - 1s - loss: 2.2321 - val_loss: 2.0562
# Epoch 70/500
# 731/731 - 1s - loss: 2.2281 - val_loss: 2.0639
# Epoch 71/500
# 731/731 - 1s - loss: 2.2280 - val_loss: 2.0515
# Epoch 72/500
# 731/731 - 1s - loss: 2.2135 - val_loss: 2.0295
# Epoch 73/500
# 731/731 - 1s - loss: 2.2120 - val_loss: 2.1336
# Epoch 74/500
# 731/731 - 1s - loss: 2.2099 - val_loss: 2.0639
# Epoch 75/500
# 731/731 - 1s - loss: 2.2057 - val_loss: 2.1129
# Epoch 76/500
# 731/731 - 1s - loss: 2.1963 - val_loss: 2.0596
# Epoch 77/500
# 731/731 - 1s - loss: 2.1985 - val_loss: 2.0440
# Epoch 78/500
# 731/731 - 1s - loss: 2.1848 - val_loss: 2.0983
# Epoch 79/500
# 731/731 - 1s - loss: 2.1973 - val_loss: 2.0497
# Epoch 80/500
# 731/731 - 1s - loss: 2.1815 - val_loss: 2.0490
# Epoch 81/500
# 731/731 - 1s - loss: 2.1736 - val_loss: 2.0297
# Epoch 82/500
# 731/731 - 1s - loss: 2.1598 - val_loss: 2.0683
# Epoch 83/500
# 731/731 - 1s - loss: 2.1834 - val_loss: 2.0317
# Epoch 84/500
# 731/731 - 1s - loss: 2.1641 - val_loss: 1.9980
# Epoch 85/500
# 731/731 - 1s - loss: 2.1653 - val_loss: 2.0234
# Epoch 86/500
# 731/731 - 1s - loss: 2.1643 - val_loss: 2.0658
# Epoch 87/500
# 731/731 - 1s - loss: 2.1561 - val_loss: 1.9956
# Epoch 88/500
# 731/731 - 1s - loss: 2.1558 - val_loss: 2.0432
# Epoch 89/500
# 731/731 - 1s - loss: 2.1576 - val_loss: 2.0227
# Epoch 90/500
# 731/731 - 1s - loss: 2.1383 - val_loss: 2.0538
# Epoch 91/500
# 731/731 - 1s - loss: 2.1407 - val_loss: 2.0215
# Epoch 92/500
# 731/731 - 1s - loss: 2.1419 - val_loss: 2.0009
# Epoch 93/500
# 731/731 - 1s - loss: 2.1263 - val_loss: 2.0300
# Epoch 94/500
# 731/731 - 1s - loss: 2.1296 - val_loss: 1.9970
# Epoch 95/500
# 731/731 - 1s - loss: 2.1312 - val_loss: 2.0050
# Epoch 96/500
# 731/731 - 1s - loss: 2.1277 - val_loss: 2.0240
# Epoch 97/500
# 731/731 - 1s - loss: 2.1248 - val_loss: 2.0651
# Epoch 98/500
# 731/731 - 1s - loss: 2.1211 - val_loss: 2.0365
# Epoch 99/500
# 731/731 - 1s - loss: 2.1244 - val_loss: 1.9973
# Epoch 100/500
# 731/731 - 1s - loss: 2.1170 - val_loss: 2.0491
# Epoch 101/500
# 731/731 - 1s - loss: 2.1189 - val_loss: 2.0014
# Epoch 102/500
# 731/731 - 1s - loss: 2.1073 - val_loss: 2.0086
# Epoch 00102: early stopping

# %%
pred = base_nn.predict(X_test_scaled)
score = math.sqrt(metrics.mean_squared_error(pred,y_test))
print("Final score (RMSE): {}".format(score))
# Out:
# Final score (RMSE): 1.5104883274259133

# %%
print(r2_score(y_train, base_nn.predict(X_train_scaled)))
print(r2_score(y_test, base_nn.predict(X_test_scaled)))
# Out:
# 0.8390070631027233
# 0.8081068884046766

# %% [markdown]
# ### Deeper Network

# %%
nn_v2 = Sequential()
nn_v2.add(Dense(X.shape[1], input_dim=X.shape[1], activation='relu'))
nn_v2.add(Dense(16, activation='relu'))
nn_v2.add(Dense(1))

earlystopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=15, verbose=2, mode='auto')

nn_v2.compile(loss='mean_squared_error', optimizer='adam')
nn_v2.fit(X_train_scaled, y_train, validation_split=0.1, callbacks=[earlystopper],
            verbose=2, epochs=500)
# Out:
# Epoch 1/500
# 731/731 - 1s - loss: 8.9173 - val_loss: 5.9126
# Epoch 2/500
# 731/731 - 1s - loss: 5.2257 - val_loss: 3.5946
# Epoch 3/500
# 731/731 - 1s - loss: 3.7611 - val_loss: 3.1506
# Epoch 4/500
# 731/731 - 1s - loss: 3.3115 - val_loss: 2.8381
# Epoch 5/500
# 731/731 - 1s - loss: 3.0652 - val_loss: 2.6511
# Epoch 6/500
# 731/731 - 1s - loss: 2.8735 - val_loss: 2.4259
# Epoch 7/500
# 731/731 - 1s - loss: 2.7134 - val_loss: 2.3384
# Epoch 8/500
# 731/731 - 1s - loss: 2.5806 - val_loss: 2.4284
# Epoch 9/500
# 731/731 - 1s - loss: 2.4858 - val_loss: 2.2922
# Epoch 10/500
# 731/731 - 1s - loss: 2.4288 - val_loss: 2.1638
# Epoch 11/500
# 731/731 - 1s - loss: 2.3240 - val_loss: 2.2244
# Epoch 12/500
# 731/731 - 1s - loss: 2.2657 - val_loss: 2.1957
# Epoch 13/500
# 731/731 - 1s - loss: 2.2080 - val_loss: 2.1210
# Epoch 14/500
# 731/731 - 1s - loss: 2.1438 - val_loss: 2.0850
# Epoch 15/500
# 731/731 - 1s - loss: 2.1221 - val_loss: 2.0578
# Epoch 16/500
# 731/731 - 1s - loss: 2.0729 - val_loss: 2.0525
# Epoch 17/500
# 731/731 - 1s - loss: 2.0303 - val_loss: 2.0622
# Epoch 18/500
# 731/731 - 1s - loss: 1.9870 - val_loss: 2.0925
# Epoch 19/500
# 731/731 - 1s - loss: 1.9328 - val_loss: 2.0428
# Epoch 20/500
# 731/731 - 1s - loss: 1.9089 - val_loss: 2.0603
# Epoch 21/500
# 731/731 - 1s - loss: 1.8685 - val_loss: 2.0591
# Epoch 22/500
# 731/731 - 1s - loss: 1.8399 - val_loss: 2.0027
# Epoch 23/500
# 731/731 - 1s - loss: 1.8161 - val_loss: 1.9430
# Epoch 24/500
# 731/731 - 1s - loss: 1.7782 - val_loss: 2.0240
# Epoch 25/500
# 731/731 - 1s - loss: 1.7665 - val_loss: 2.0681
# Epoch 26/500
# 731/731 - 1s - loss: 1.7325 - val_loss: 1.8952
# Epoch 27/500
# 731/731 - 1s - loss: 1.7216 - val_loss: 1.9191
# Epoch 28/500
# 731/731 - 1s - loss: 1.6854 - val_loss: 1.9676
# Epoch 29/500
# 731/731 - 1s - loss: 1.6776 - val_loss: 1.9663
# Epoch 30/500
# 731/731 - 1s - loss: 1.6437 - val_loss: 1.9516
# Epoch 31/500
# 731/731 - 1s - loss: 1.6351 - val_loss: 2.1237
# Epoch 32/500
# 731/731 - 1s - loss: 1.6236 - val_loss: 1.9323
# Epoch 33/500
# 731/731 - 1s - loss: 1.5814 - val_loss: 2.1307
# Epoch 34/500
# 731/731 - 1s - loss: 1.5833 - val_loss: 2.2317
# Epoch 35/500
# 731/731 - 1s - loss: 1.5867 - val_loss: 2.1368
# Epoch 36/500
# 731/731 - 1s - loss: 1.5459 - val_loss: 2.2938
# Epoch 37/500
# 731/731 - 1s - loss: 1.5425 - val_loss: 2.1255
# Epoch 38/500
# 731/731 - 1s - loss: 1.5233 - val_loss: 2.0257
# Epoch 39/500
# 731/731 - 1s - loss: 1.5067 - val_loss: 1.9208
# Epoch 40/500
# 731/731 - 1s - loss: 1.5252 - val_loss: 1.8644
# Epoch 41/500
# 731/731 - 1s - loss: 1.5114 - val_loss: 1.9185
# Epoch 42/500
# 731/731 - 1s - loss: 1.4865 - val_loss: 1.9791
# Epoch 43/500
# 731/731 - 1s - loss: 1.4655 - val_loss: 2.0922
# Epoch 44/500
# 731/731 - 1s - loss: 1.4741 - val_loss: 2.1226
# Epoch 45/500
# 731/731 - 1s - loss: 1.4402 - val_loss: 1.9776
# Epoch 46/500
# 731/731 - 1s - loss: 1.4592 - val_loss: 1.9660
# Epoch 47/500
# 731/731 - 1s - loss: 1.4406 - val_loss: 2.4635
# Epoch 48/500
# 731/731 - 1s - loss: 1.4507 - val_loss: 1.9887
# Epoch 49/500
# 731/731 - 1s - loss: 1.4287 - val_loss: 2.0135
# Epoch 50/500
# 731/731 - 1s - loss: 1.4103 - val_loss: 1.9891
# Epoch 51/500
# 731/731 - 1s - loss: 1.4380 - val_loss: 2.1823
# Epoch 52/500
# 731/731 - 1s - loss: 1.4205 - val_loss: 1.9103
# Epoch 53/500
# 731/731 - 1s - loss: 1.4099 - val_loss: 2.0623
# Epoch 54/500
# 731/731 - 1s - loss: 1.4122 - val_loss: 2.0135
# Epoch 55/500
# 731/731 - 1s - loss: 1.3814 - val_loss: 1.9306
# Epoch 00055: early stopping

# %%
pred = nn_v2.predict(X_test_scaled)
score = math.sqrt(metrics.mean_squared_error(pred,y_test))
print("Final score (RMSE): {}".format(score))
# Out:
# Final score (RMSE): 1.4773187787575688

# %%
print(r2_score(y_train, nn_v2.predict(X_train_scaled)))
print(r2_score(y_test, nn_v2.predict(X_test_scaled)))
# Out:
# 0.8909205432179848
# 0.8164421024357593

# %% [markdown]
# ## Different Features

# %% [markdown]
# - Considering eviction.filings is consistantly the most important feature, it is worth running basemodels that utilize eviction.filing.rate
# - Based on the eviction.filing.rate and eviction.rate calculations (# eviction filings; evictions/# renter occupied households), I will need to drop any features that would give the model the ability to perfectly calculate the eviction rate

# %%
drop_pop_df = tracts_df.drop(['renter.occupied.households', 'pct.renter.occupied', 'ef.ratio', 'eviction.filings', 'Unnamed: 0', 'name', 'GEOID', 
                              'male', 'pct.white', 'state'], axis=1)

# %%
region_dummies = pd.get_dummies(drop_pop_df['region'], drop_first=True)
drop_pop_df = pd.concat([drop_pop_df, region_dummies], axis=1)
drop_pop_df.drop('region', axis=1, inplace=True)

# %%
X = drop_pop_df.drop("eviction.rate", axis = 1)
y = drop_pop_df['eviction.rate']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 25)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
xgb_base = XGBRegressor()
xgb_base_model = xgb_base.fit(X_train_scaled, y_train)

# %%
rf_report(xgb_base)
# Out:
# Variance --------------------------------------------
# Train Variance: 0.9760190436447717
# Test Variance: 0.8929972214172248
# Max Error --------------------------------------------
# Max Error Train: 4.598149871826173
# Max Error Test: 25.55285568237305
# RMSE --------------------------------------------
# Train RMSE: 0.5540068077052184
# Test RMSE: 1.1281099662807605
# R2 --------------------------------------------
# R2 Train: 0.9760190423737297
# R2 Test: 0.8929645818427344

# %%
plot_feature_importances_base(xgb_base_model)

# %%
xgb_v2 = XGBRegressor()

param_grid = {
    'learning_rate' : [0.1, 0.2],
    'max_depth': [4, 6, 8],
    'min_child_weight': [1, 2],
    'sub_sample': [0.5, 0.7],
    
}

xgb_v2_model = GridSearchCV(estimator = xgb_v2, param_grid=param_grid, cv=3)
xgb_v2_model.fit(X_train_scaled, y_train)
# Out:
# [16:10:02] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:04] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:05] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:07] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:08] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:10] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:11] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:14] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:17] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:19] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:24] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:25] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:30] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:33] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:38] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:41] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:43] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:46] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:48] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:51] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:53] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [16:10:56] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:10:59] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:02] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:05] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:08] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:12] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:15] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:18] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:24] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:27] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:30] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:33] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:37] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:40] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:41] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:43] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:44] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:46] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:48] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:49] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:51] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [16:11:52] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:54] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:55] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:57] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:11:59] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:12:01] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:12:03] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:12:06] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:12:08] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:12:10] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:12:13] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:12:17] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:12:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:12:26] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:12:30] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:12:33] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:12:36] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:12:39] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:12:42] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:12:45] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:12:48] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:12:52] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [16:12:56] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:13:00] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:13:05] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:13:10] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:13:15] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:13:19] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:13:24] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { sub_sample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# GridSearchCV(cv=3,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, gamma=None,
#                                     gpu_id=None, importance_type='gain',
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_delta_step=None,
#                                     max_depth=None, min_child_weight=None,
#                                     missing=nan, monotone_constraints=None,
#                                     n_estimators=100, n_jobs=None,
#                                     num_parallel_tree=None, random_state=None,
#                                     reg_alpha=None, reg_lambda=None,
#                                     scale_pos_weight=None, subsample=None,
#                                     tree_method=None, validate_parameters=None,
#                                     verbosity=None),
#              param_grid={'learning_rate': [0.1, 0.2], 'max_depth': [4, 6, 8],
#                          'min_child_weight': [1, 2], 'sub_sample': [0.5, 0.7]})

# %%
report_grid(xgb_v2_model)
# Out:
# {'learning_rate': 0.2, 'max_depth': 6, 'min_child_weight': 2, 'sub_sample': 0.5}
# None
# Variance --------------------------------------------
# Train Variance: 0.9682715004563982
# Test Variance: 0.8976130895795574
# Max Error --------------------------------------------
# Max Error Train: 7.789453887939452
# Max Error Test: 27.477420043945315
# RMSE --------------------------------------------
# Train RMSE: 0.6372452521061793
# Test RMSE: 1.1034693992285847
# R2 --------------------------------------------
# R2 Train: 0.9682715003828244
# R2 Test: 0.8975893255811879

# %%
plot_feature_importances(xgb_v2_model)

# %% [markdown]
# ## MLN

# %%
base_nn = Sequential()
base_nn.add(Dense(X.shape[1], input_dim=X.shape[1], activation='relu'))
base_nn.add(Dense(1))

earlystopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=15, verbose=2, mode='auto')

base_nn.compile(loss='mean_squared_error', optimizer='adam')
base_nn.fit(X_train_scaled, y_train, validation_split=0.1, callbacks=[earlystopper],
            verbose=2, epochs=500)
# Out:
# Epoch 1/500
# 731/731 - 1s - loss: 5.8933 - val_loss: 2.7854
# Epoch 2/500
# 731/731 - 1s - loss: 2.4951 - val_loss: 1.9390
# Epoch 3/500
# 731/731 - 1s - loss: 2.1720 - val_loss: 1.7986
# Epoch 4/500
# 731/731 - 1s - loss: 2.0533 - val_loss: 1.6778
# Epoch 5/500
# 731/731 - 1s - loss: 1.9805 - val_loss: 1.6325
# Epoch 6/500
# 731/731 - 1s - loss: 1.9216 - val_loss: 1.6223
# Epoch 7/500
# 731/731 - 1s - loss: 1.8848 - val_loss: 1.5899
# Epoch 8/500
# 731/731 - 1s - loss: 1.8538 - val_loss: 1.5519
# Epoch 9/500
# 731/731 - 1s - loss: 1.8245 - val_loss: 1.5406
# Epoch 10/500
# 731/731 - 1s - loss: 1.8001 - val_loss: 1.5515
# Epoch 11/500
# 731/731 - 1s - loss: 1.7612 - val_loss: 1.5513
# Epoch 12/500
# 731/731 - 1s - loss: 1.7625 - val_loss: 1.5218
# Epoch 13/500
# 731/731 - 1s - loss: 1.7372 - val_loss: 1.4862
# Epoch 14/500
# 731/731 - 1s - loss: 1.7280 - val_loss: 1.4856
# Epoch 15/500
# 731/731 - 1s - loss: 1.7116 - val_loss: 1.4925
# Epoch 16/500
# 731/731 - 1s - loss: 1.6933 - val_loss: 1.4961
# Epoch 17/500
# 731/731 - 1s - loss: 1.6946 - val_loss: 1.4705
# Epoch 18/500
# 731/731 - 1s - loss: 1.6753 - val_loss: 1.4611
# Epoch 19/500
# 731/731 - 1s - loss: 1.6596 - val_loss: 1.4591
# Epoch 20/500
# 731/731 - 1s - loss: 1.6494 - val_loss: 1.4603
# Epoch 21/500
# 731/731 - 1s - loss: 1.6498 - val_loss: 1.4635
# Epoch 22/500
# 731/731 - 1s - loss: 1.6330 - val_loss: 1.4346
# Epoch 23/500
# 731/731 - 1s - loss: 1.6286 - val_loss: 1.4543
# Epoch 24/500
# 731/731 - 1s - loss: 1.6247 - val_loss: 1.4575
# Epoch 25/500
# 731/731 - 1s - loss: 1.6132 - val_loss: 1.4578
# Epoch 26/500
# 731/731 - 1s - loss: 1.6071 - val_loss: 1.4416
# Epoch 27/500
# 731/731 - 1s - loss: 1.6028 - val_loss: 1.4492
# Epoch 28/500
# 731/731 - 1s - loss: 1.5960 - val_loss: 1.4399
# Epoch 29/500
# 731/731 - 1s - loss: 1.5853 - val_loss: 1.4502
# Epoch 30/500
# 731/731 - 1s - loss: 1.5851 - val_loss: 1.4420
# Epoch 31/500
# 731/731 - 1s - loss: 1.5820 - val_loss: 1.4331
# Epoch 32/500
# 731/731 - 1s - loss: 1.5694 - val_loss: 1.4441
# Epoch 33/500
# 731/731 - 1s - loss: 1.5682 - val_loss: 1.4245
# Epoch 34/500
# 731/731 - 1s - loss: 1.5581 - val_loss: 1.4454
# Epoch 35/500
# 731/731 - 1s - loss: 1.5546 - val_loss: 1.4238
# Epoch 36/500
# 731/731 - 1s - loss: 1.5524 - val_loss: 1.4057
# Epoch 37/500
# 731/731 - 1s - loss: 1.5400 - val_loss: 1.4305
# Epoch 38/500
# 731/731 - 1s - loss: 1.5334 - val_loss: 1.4042
# Epoch 39/500
# 731/731 - 1s - loss: 1.5331 - val_loss: 1.4306
# Epoch 40/500
# 731/731 - 1s - loss: 1.5153 - val_loss: 1.4146
# Epoch 41/500
# 731/731 - 1s - loss: 1.5205 - val_loss: 1.4169
# Epoch 42/500
# 731/731 - 1s - loss: 1.5123 - val_loss: 1.3893
# Epoch 43/500
# 731/731 - 1s - loss: 1.4986 - val_loss: 1.4674
# Epoch 44/500
# 731/731 - 1s - loss: 1.5004 - val_loss: 1.3998
# Epoch 45/500
# 731/731 - 1s - loss: 1.4910 - val_loss: 1.3712
# Epoch 46/500
# 731/731 - 1s - loss: 1.4861 - val_loss: 1.3826
# Epoch 47/500
# 731/731 - 1s - loss: 1.4794 - val_loss: 1.3861
# Epoch 48/500
# 731/731 - 1s - loss: 1.4784 - val_loss: 1.3649
# Epoch 49/500
# 731/731 - 1s - loss: 1.4687 - val_loss: 1.3765
# Epoch 50/500
# 731/731 - 1s - loss: 1.4725 - val_loss: 1.3973
# Epoch 51/500
# 731/731 - 1s - loss: 1.4735 - val_loss: 1.3925
# Epoch 52/500
# 731/731 - 1s - loss: 1.4640 - val_loss: 1.3833
# Epoch 53/500
# 731/731 - 1s - loss: 1.4589 - val_loss: 1.3944
# Epoch 54/500
# 731/731 - 1s - loss: 1.4607 - val_loss: 1.3860
# Epoch 55/500
# 731/731 - 1s - loss: 1.4493 - val_loss: 1.3765
# Epoch 56/500
# 731/731 - 1s - loss: 1.4435 - val_loss: 1.3932
# Epoch 57/500
# 731/731 - 1s - loss: 1.4434 - val_loss: 1.4218
# Epoch 58/500
# 731/731 - 1s - loss: 1.4360 - val_loss: 1.3854
# Epoch 59/500
# 731/731 - 1s - loss: 1.4407 - val_loss: 1.4005
# Epoch 60/500
# 731/731 - 1s - loss: 1.4428 - val_loss: 1.3774
# Epoch 61/500
# 731/731 - 1s - loss: 1.4307 - val_loss: 1.3764
# Epoch 62/500
# 731/731 - 1s - loss: 1.4295 - val_loss: 1.3701
# Epoch 63/500
# 731/731 - 1s - loss: 1.4243 - val_loss: 1.4161
# Epoch 00063: early stopping

# %%
pred = base_nn.predict(X_test_scaled)
score = math.sqrt(metrics.mean_squared_error(pred,y_test))
print("Final score (RMSE): {}".format(score))
# Out:
# Final score (RMSE): 1.1704857225953178

# %%
print(r2_score(y_train, base_nn.predict(X_train_scaled)))
print(r2_score(y_test, base_nn.predict(X_test_scaled)))
# Out:
# 0.889457807635865
# 0.8847723037115642

# %% [markdown]
# ### Deeper Network

# %%
nn_v2 = Sequential()
nn_v2.add(Dense(X.shape[1], input_dim=X.shape[1], activation='relu'))
nn_v2.add(Dense(16, activation='relu'))
nn_v2.add(Dense(1))

earlystopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=15, verbose=2, mode='auto')

nn_v2.compile(loss='mean_squared_error', optimizer='adam')
nn_v2.fit(X_train_scaled, y_train, validation_split=0.1, callbacks=[earlystopper],
            verbose=2, epochs=500)
# Out:
# Epoch 1/500
# 731/731 - 1s - loss: 5.5404 - val_loss: 2.1839
# Epoch 2/500
# 731/731 - 1s - loss: 2.3439 - val_loss: 1.8089
# Epoch 3/500
# 731/731 - 1s - loss: 2.1032 - val_loss: 1.6861
# Epoch 4/500
# 731/731 - 1s - loss: 1.9863 - val_loss: 1.6855
# Epoch 5/500
# 731/731 - 1s - loss: 1.9019 - val_loss: 1.6190
# Epoch 6/500
# 731/731 - 1s - loss: 1.8171 - val_loss: 1.5715
# Epoch 7/500
# 731/731 - 1s - loss: 1.7685 - val_loss: 1.6024
# Epoch 8/500
# 731/731 - 1s - loss: 1.7118 - val_loss: 1.4834
# Epoch 9/500
# 731/731 - 1s - loss: 1.6548 - val_loss: 1.4592
# Epoch 10/500
# 731/731 - 1s - loss: 1.6248 - val_loss: 1.4628
# Epoch 11/500
# 731/731 - 1s - loss: 1.5771 - val_loss: 1.4478
# Epoch 12/500
# 731/731 - 1s - loss: 1.5393 - val_loss: 1.4583
# Epoch 13/500
# 731/731 - 1s - loss: 1.5308 - val_loss: 1.3831
# Epoch 14/500
# 731/731 - 1s - loss: 1.4878 - val_loss: 1.4000
# Epoch 15/500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-110-8d87b9cacc5a> in <module>
#       7
#       8 nn_v2.compile(loss='mean_squared_error', optimizer='adam')
# ----> 9 nn_v2.fit(X_train_scaled, y_train, validation_split=0.1, callbacks=[earlystopper],
#      10             verbose=2, epochs=500)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1841       `args` and `kwargs`.
#    1842     """
# -> 1843     return self._call_flat(
#    1844         [t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1845          if isinstance(t, (ops.Tensor,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1921         and executing_eagerly):
#    1922       # No tape is watching; skip to running the function.
# -> 1923       return self._build_call_outputs(self._inference_function.call(
#    1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543       with _InterpolateFunctionError(self):
#     544         if cancellation_manager is None:
# --> 545           outputs = execute.execute(
#     546               str(self.signature.name),
#     547               num_outputs=self._num_outputs,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
pred = nn_v2.predict(X_test_scaled)
score = math.sqrt(metrics.mean_squared_error(pred,y_test))
print("Final score (RMSE): {}".format(score))

# %%
print(r2_score(y_train, nn_v2.predict(X_train_scaled)))
print(r2_score(y_test, nn_v2.predict(X_test_scaled)))

# %% [markdown]
# ### Wider Network

# %%
nn_v2 = Sequential()
nn_v2.add(Dense(X.shape[1]*2, input_dim=X.shape[1], activation='relu'))
nn_v2.add(Dense(25, activation='relu'))
nn_v2.add(Dense(1))

earlystopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=15, verbose=2, mode='auto')

nn_v2.compile(loss='mean_squared_error', optimizer='adam')
nn_v2.fit(X_train_scaled, y_train, validation_split=0.1, callbacks=[earlystopper],
            verbose=2, epochs=500)

# %%
pred = nn_v2.predict(X_test_scaled)
score = math.sqrt(metrics.mean_squared_error(pred,y_test))
print("Final score (RMSE): {}".format(score))


print(r2_score(y_train, nn_v2.predict(X_train_scaled)))
print(r2_score(y_test, nn_v2.predict(X_test_scaled)))

# %%
nn_v2 = Sequential()
nn_v2.add(Dense(X.shape[1]*2, input_dim=X.shape[1], activation='relu'))
nn_v2.add(Dense(25, activation='relu'))
nn_v2.add(Dense(16, activation='relu'))
nn_v2.add(Dense(1))

earlystopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=15, verbose=2, mode='auto')

nn_v2.compile(loss='mean_squared_error', optimizer='adam')
nn_v2.fit(X_train_scaled, y_train, validation_split=0.1, callbacks=[earlystopper],
            verbose=2, epochs=500)

# %%
pred = nn_v2.predict(X_test_scaled)
score = math.sqrt(metrics.mean_squared_error(pred,y_test))
print("Final score (RMSE): {}".format(score))


print(r2_score(y_train, nn_v2.predict(X_train_scaled)))
print(r2_score(y_test, nn_v2.predict(X_test_scaled)))

# %% [markdown]
# ### Deeper Still

# %%
# nn_v2 = Sequential()
# nn_v2.add(Dense(X.shape[1], input_dim=X.shape[1], activation='relu'))
# nn_v2.add(Dense(16, activation='relu'))
# nn_v2.add(Dense(16, activation='relu'))
# nn_v2.add(Dense(1))

# earlystopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=15, verbose=2, mode='auto')

# nn_v2.compile(loss='mean_squared_error', optimizer= optimizers.Adam(learning_rate = 0.005))
# history = nn_v2.fit(X_train_scaled, y_train, validation_split=0.1, callbacks=[earlystopper],
#             verbose=2, epochs=500)

# %%
# history_dict=history.history

# %%
# pred = nn_v2.predict(X_test_scaled)
# score = math.sqrt(metrics.mean_squared_error(pred,y_test))
# print("Final score (RMSE): {}".format(score))


# print(r2_score(y_train, nn_v2.predict(X_train_scaled)))
# print(r2_score(y_test, nn_v2.predict(X_test_scaled)))

# %%
# loss_values = history_dict['loss']
# val_loss_values=history_dict['val_loss']
# plt.figure(figsize=(20,13))
# plt.plot(loss_values,'bo',label='training loss')
# plt.plot(val_loss_values,'r',label='val training loss')

# %%
# history.history

# %%
# nn_v3 = Sequential()
# nn_v3.add(Dense(X.shape[1], input_dim=X.shape[1], activation='relu'))
# nn_v3.add(Dense(X.shape[1], activation='relu'))
# nn_v3.add(Dense(X.shape[1], activation='relu'))
# nn_v3.add(Dense(X.shape[1], activation='relu'))
# nn_v3.add(Dense(X.shape[1]//2, activation='relu'))
# nn_v3.add(Dense(1))

# earlystopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=15, verbose=2, mode='auto')

# nn_v3.compile(loss='mean_squared_error', optimizer='adam')
# nn_v3.fit(X_train_scaled, y_train, validation_split=0.1, callbacks=[earlystopper],
#             verbose=2, epochs=500)

# %%
# pred = nn_v3.predict(X_test_scaled)
# score = math.sqrt(metrics.mean_squared_error(pred,y_test))
# print("Final score (RMSE): {}".format(score))

# %%
# print(r2_score(y_train, nn_v3.predict(X_train_scaled)))
# print(r2_score(y_test, nn_v3.predict(X_test_scaled)))

# %% [markdown]
# # Outlier Detection and Removal

# %% [markdown]
# **OBSERVATION**
# - Thus far the highest r2 values achieved (via supervised learning techniques) have been 87% (XGBoost)
# - Considering I have not removed any outliers after initial cleaning, detecting and removing these outliers could yield better results

# %% [markdown]
# ## Isolation Forest

# %% [markdown]
# - I am starting with Isolation Forset as it functions well with multi-dimensional data

# %%
from sklearn.ensemble import IsolationForest

# %%
fig, ax = plt.subplots(figsize=(20, 5))
ax = sns.boxplot(y)

# %%
outliers = y > 9

# %%
len(y)/outliers.sum()
# Out:
# 14.500209467951404

# %% [markdown]
# **OBSERVATION**
# - Based on the boxplot and calculation above, approx 15% of eviction rates are outliers
# - I will use this percentage as the maximum contamination, and train several models with decreasing contaminations to see which gives the best R2

# %%
i = [0.15, 0.12, 0.1, 0.08, 0.06, 0.04, 0.02, 0.01, 0.005]

# %%
def iso_forest(contamination_list):

    contamination_dict = {}

    for contamination in contamination_list:
        print('CURRENT CONTAMINATION: ', contamination)
        
        #fitting IsolationForest to all data
        isoforest = IsolationForest(contamination = contamination, n_estimators=drop_pop_df.shape[1], random_state=42)
        isoforest_model =isoforest.fit(X)
        
        #assinging IsolationForest predictions (-1 = Outlier, 1 = Non-Outlier) 
        eviction_rate_outliers = pd.Series(isoforest_model.predict(X))

        
        iso_df = tracts_df.drop(['renter.occupied.households', 'pct.renter.occupied', 'ef.ratio', 'eviction.filings', 
                                 'Unnamed: 0', 'name', 'GEOID', 
                                  'male', 'pct.white', 'state'], axis=1)
        region_dummies = pd.get_dummies(iso_df['region'], drop_first=True)
        iso_df = pd.concat([iso_df, region_dummies], axis=1)
        iso_df.drop('region', axis=1, inplace=True)

        iso_tracts = iso_df
        iso_tracts.reset_index(inplace=True)
        iso_tracts.drop('index', axis=1, inplace=True)

        #iterating through IsolationForest predictions
        for i in range(len(eviction_rate_outliers)):
            if eviction_rate_outliers[i] == -1:
                #if the datapoint is an outlier, drop it from the dataset
                iso_tracts.drop(i, inplace=True)


        #preprocessing data        
        X2 = iso_tracts.drop("eviction.rate", axis = 1)
        y2 = iso_tracts['eviction.rate']

        #making certain variable accessible outside of function to be later used in gridsearch optimization
        X2_train, X2_test, iso_forest.y2_train, y2_test = train_test_split(X2, y2, test_size = 0.25, random_state = 25)

        #scaling data
        scaler = StandardScaler()

        iso_forest.X2_train_scaled = scaler.fit_transform(X2_train)
        X2_test_scaled = scaler.transform(X2_test)
    
        #training model on OUTLIER REMOVED data
        iso_forest.xgb_iso = XGBRegressor().fit(iso_forest.X2_train_scaled, iso_forest.y2_train)
        
        rf_report(iso_forest.xgb_iso)
        
        #populating contamination_dict with contamination's corresponding R2 score
        #model is tested on FULL DATA (outliers included)
        contamination_dict[str(contamination)] = r2_score(y_test, iso_forest.xgb_iso.predict(X_test_scaled))   
    print(contamination_dict)

# %%
iso_forest(i)
# Out:
# CURRENT CONTAMINATION:  0.15
# Variance --------------------------------------------
# Train Variance: 0.8512968439896496
# Test Variance: 0.874851444798172
# Max Error --------------------------------------------
# Max Error Train: 43.089692164201004
# Max Error Test: 24.178755950927737
# RMSE --------------------------------------------
# Train RMSE: 1.4059513554652374
# Test RMSE: 1.2456935113242846
# R2 --------------------------------------------
# R2 Train: 0.8455539134325731
# R2 Test: 0.8694890224663827
# CURRENT CONTAMINATION:  0.12
# Variance --------------------------------------------
# Train Variance: 0.871535734383533
# Test Variance: 0.865687908939196
# Max Error --------------------------------------------
# Max Error Train: 41.309637298583986
# Max Error Test: 53.924300861358645
# RMSE --------------------------------------------
# Train RMSE: 1.2991417398191418
# Test RMSE: 1.2773554920781156
# R2 --------------------------------------------
# R2 Train: 0.8681289720662051
# R2 Test: 0.8627702736636467
# CURRENT CONTAMINATION:  0.1
# Variance --------------------------------------------
# Train Variance: 0.8851708474482244
# Test Variance: 0.8953687236543206
# Max Error --------------------------------------------
# Max Error Train: 32.1967444904034
# Max Error Test: 20.54922027587891
# RMSE --------------------------------------------
# Train RMSE: 1.2290575586924184
# Test RMSE: 1.129464074308335
# R2 --------------------------------------------
# R2 Train: 0.881973164542698
# R2 Test: 0.8927074712596069
# CURRENT CONTAMINATION:  0.08
# Variance --------------------------------------------
# Train Variance: 0.8893059372882168
# Test Variance: 0.8803376607079939
# Max Error --------------------------------------------
# Max Error Train: 35.11300468444824
# Max Error Test: 46.26868171691895
# RMSE --------------------------------------------
# Train RMSE: 1.2034306791178098
# Test RMSE: 1.2047479494687863
# R2 --------------------------------------------
# R2 Train: 0.8868437682595766
# R2 Test: 0.8779277274631369
# CURRENT CONTAMINATION:  0.06
# Variance --------------------------------------------
# Train Variance: 0.8927440917827489
# Test Variance: 0.8794032484477139
# Max Error --------------------------------------------
# Max Error Train: 36.46165107727051
# Max Error Test: 46.82938976287842
# RMSE --------------------------------------------
# Train RMSE: 1.1787348018482875
# Test RMSE: 1.2023853262863387
# R2 --------------------------------------------
# R2 Train: 0.8914403258330985
# R2 Test: 0.87840604822878
# CURRENT CONTAMINATION:  0.04
# Variance --------------------------------------------
# Train Variance: 0.8994576129480284
# Test Variance: 0.9101486118780324
# Max Error --------------------------------------------
# Max Error Train: 38.36988245646159
# Max Error Test: 41.67907638549805
# RMSE --------------------------------------------
# Train RMSE: 1.1406052799163047
# Test RMSE: 1.0378559802204208
# R2 --------------------------------------------
# R2 Train: 0.8983500722969102
# R2 Test: 0.9094061279215415
# CURRENT CONTAMINATION:  0.02
# Variance --------------------------------------------
# Train Variance: 0.9322038023637502
# Test Variance: 0.9170769823754712
# Max Error --------------------------------------------
# Max Error Train: 29.25139986673991
# Max Error Test: 39.386620712280276
# RMSE --------------------------------------------
# Train RMSE: 0.9342648756368166
# Test RMSE: 0.9944997856276292
# R2 --------------------------------------------
# R2 Train: 0.9318012582787348
# R2 Test: 0.9168171060030859
# CURRENT CONTAMINATION:  0.01
# Variance --------------------------------------------
# Train Variance: 0.9389395331784396
# Test Variance: 0.9287528274387101
# Max Error --------------------------------------------
# Max Error Train: 18.4009126663208
# Max Error Test: 26.12052459716797
# RMSE --------------------------------------------
# Train RMSE: 0.8860705955629664
# Test RMSE: 0.9217392236884272
# R2 --------------------------------------------
# R2 Train: 0.9386558761336391
# R2 Test: 0.9285436586992769
# CURRENT CONTAMINATION:  0.005
# Variance --------------------------------------------
# Train Variance: 0.9408333029041689
# Test Variance: 0.9431365675977823
# Max Error --------------------------------------------
# Max Error Train: 29.093093554178864
# Max Error Test: 13.38993278503418
# RMSE --------------------------------------------
# Train RMSE: 0.8703884858179546
# Test RMSE: 0.8223394538312156
# R2 --------------------------------------------
# R2 Train: 0.9408080573887537
# R2 Test: 0.9431242819884292
# {'0.15': 0.8694890224663827, '0.12': 0.8627702736636467, '0.1': 0.8927074712596069, '0.08': 0.8779277274631369, '0.06': 0.87840604822878, '0.04': 0.9094061279215415, '0.02': 0.9168171060030859, '0.01': 0.9285436586992769, '0.005': 0.9431242819884292}

# %% [markdown]
# **OBSERVATION**
# - Contamination = 0.04 returns best R2(0.924) and RMSE(0.965)
#     - overall improvement of ~5% R2 compared to best performing model before outlier removal
# - Testing set outperforms training set, this suggests that the model is well generalized

# %%
iso_forest([0.001, 0.0005, 0.00001 ])
# Out:
# CURRENT CONTAMINATION:  0.001
# Variance --------------------------------------------
# Train Variance: 0.9453244429976554
# Test Variance: 0.9418981921616099
# Max Error --------------------------------------------
# Max Error Train: 35.36319923400879
# Max Error Test: 12.085171127319335
# RMSE --------------------------------------------
# Train RMSE: 0.8365395347275469
# Test RMSE: 0.8316343901207284
# R2 --------------------------------------------
# R2 Train: 0.9453224231344023
# R2 Test: 0.9418312785116154
# CURRENT CONTAMINATION:  0.0005
# Variance --------------------------------------------
# Train Variance: 0.9467318365657652
# Test Variance: 0.9436749030499723
# Max Error --------------------------------------------
# Max Error Train: 27.21333679199219
# Max Error Test: 11.03135597229004
# RMSE --------------------------------------------
# Train RMSE: 0.8258112700517636
# Test RMSE: 0.8191410437683143
# R2 --------------------------------------------
# R2 Train: 0.946715863785838
# R2 Test: 0.9435658468522696
# CURRENT CONTAMINATION:  1e-05
# Variance --------------------------------------------
# Train Variance: 0.9593709899720845
# Test Variance: 0.9154104098447915
# Max Error --------------------------------------------
# Max Error Train: 17.17888153076172
# Max Error Test: 26.67714996337891
# RMSE --------------------------------------------
# Train RMSE: 0.7211476876652883
# Test RMSE: 1.003251333776159
# R2 --------------------------------------------
# R2 Train: 0.9593664516101559
# R2 Test: 0.9153466538174218
# {'0.001': 0.9418312785116154, '0.0005': 0.9435658468522696, '1e-05': 0.9153466538174218}

# %%
iso_forest([0.0005])
# Out:
# CURRENT CONTAMINATION:  0.0005
# Variance --------------------------------------------
# Train Variance: 0.9467318365657652
# Test Variance: 0.9436749030499723
# Max Error --------------------------------------------
# Max Error Train: 27.21333679199219
# Max Error Test: 11.03135597229004
# RMSE --------------------------------------------
# Train RMSE: 0.8258112700517636
# Test RMSE: 0.8191410437683143
# R2 --------------------------------------------
# R2 Train: 0.946715863785838
# R2 Test: 0.9435658468522696
# {'0.0005': 0.9435658468522696}

# %%
plot_feature_importances_base(iso_forest.xgb_iso)

# %% [markdown]
# **OBSERVATION**
# - Feature importances have not changed much

# %%
param_grid = {
    'learning_rate' : [0.1, 0.2],
    'max_depth': [4, 6, 8],
    'min_child_weight': [1, 2],
    'sub_sample': [0.5, 0.7],
    
}

xgb_iso_model = GridSearchCV(estimator = XGBRegressor(), param_grid=param_grid, cv=3).fit(iso_forest.X2_train_scaled, iso_forest.y2_train)

# %%
rf_report(xgb_iso_model)

# %% [markdown]
# **OBSERVATION**
# - Grid optimization does not lead to improvements

# %% [markdown]
# # Permutation Importance

# %% [markdown]
# - Feature importances for tree based models can often be misleading
# - Plotting permutation importances may offer additional insight into how the model is using features

# %%
from sklearn.inspection import permutation_importance

result = permutation_importance(iso_forest.xgb_iso, X_test_scaled, y_test, n_repeats=10, random_state=0)

# %%
plt.subplots(figsize=(18,10))
feature_importance = iso_forest.xgb_iso.feature_importances_
sorted_idx = result.importances_mean.argsort()

plt.boxplot(result.importances[sorted_idx].T,
            vert=False, labels=np.array(X_train.columns)[sorted_idx])
plt.title("Permutation Importance (test set)")

plt.show()

# %% [markdown]
# ### Variance Threshold

# %%
from sklearn.feature_selection import SelectFromModel

# %%
m = SelectFromModel(XGBRegressor(learning_rate=0.2,
                                max_depth=6,
                                min_child_weight=2,
                                sub_sample=0.5))

m.fit(X_train_scaled, y_train)

# %%
m.transform(X_train_scaled).shape

# %%
m.score(X_test_scaled, y_test)

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
var_thresh=VarianceThreshold(threshold=0.4)
var_thresh.fit(X_train_scaled)
sum(var_thresh.get_support())

# %%
var_thresh.get_support()

# %%
constant_columns = [column for column in X.columns
                   if column not in X.columns[var_thresh.get_support()]]

# %%
constant_columns

# %%
feature_select_df = drop_pop_df
for col in constant_columns:
    feature_select_df.drop(col, axis=1, inplace=True)

# %%
X = feature_select_df.drop("eviction.rate", axis = 1)
y = feature_select_df['eviction.rate']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 25)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
xgb_base = XGBRegressor()
xgb_base_model = xgb_base.fit(X_train_scaled, y_train)

# %%
rf_report(xgb_base_model)

# %%
xgb_v2 = XGBRegressor()

param_grid = {
    'learning_rate' : [0.1, 0.2],
    'max_depth': [4, 6, 8],
    'min_child_weight': [1, 2],
    'sub_sample': [0.5, 0.7],
    
}

xgb_v2_model = GridSearchCV(estimator = xgb_v2, param_grid=param_grid, cv=3)
xgb_v2_model.fit(X_train_scaled, y_train)

# %%
report_grid(xgb_v2_model)

# %% [markdown]
# ### RFE

# %%
sel = SelectFromModel(xgb_perm)
sel.fit(X_train_scaled, y_train)

# %%
constant_columns = [column for column in X.columns
                   if column not in X.columns[sel.get_support()]]

# %%
constant_columns

# %%
feature_select_df = drop_pop_df
for col in constant_columns:
    feature_select_df.drop(col, axis=1, inplace=True)

# %%
X1 = feature_select_df.drop("eviction.rate", axis = 1)
y1 = feature_select_df['eviction.rate']

X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size = 0.25, random_state = 25)

scaler = StandardScaler()

X1_train_scaled = scaler.fit_transform(X1_train)
X1_test_scaled = scaler.transform(X1_test)

# %%
xgb_v2 = XGBRegressor()

param_grid = {
    'learning_rate' : [0.1, 0.2],
    'max_depth': [4, 6, 8],
    'min_child_weight': [1, 2],
    'sub_sample': [0.5, 0.7],
    
}

xgb_v2_model = GridSearchCV(estimator = xgb_v2, param_grid=param_grid, cv=3)
xgb_v2_model.fit(X1_train_scaled, y1_train)

# %%
rmse_train = math.sqrt(mean_squared_error(y1_train, xgb_v2_model.predict(X1_train_scaled)))
rmse_test = math.sqrt(mean_squared_error(y1_test, xgb_v2_model.predict(X1_test_scaled)))
    
    #calculating R2
r_sq_train = r2_score(y1_train, xgb_v2_model.predict(X1_train_scaled))
r_sq_test = r2_score(y1_test, xgb_v2_model.predict(X1_test_scaled))

print(rmse_train)
print(rmse_test)
print(r_sq_train)
print(r_sq_test)

# %% [markdown]
# # Counterfactuals

# %%
pip install ceml

# %%
from ceml.sklearn import generate_counterfactual
