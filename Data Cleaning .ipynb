# %% [markdown]
# # State Selection

# %% [markdown]
# **State selection criteria:**
# 1. Data available from 2000 - 2016
# 2. Data available for most counties from 2000 - 2016

# %% [markdown]
# **Selected States**
# 1. Michigan
# 2. Pennsylvania
# 3. Delaware
# 4. Nevada
# 5. Washington

# %% [markdown]
# # Importing Data

# %%
import pandas as pd

# %%
tracts_df = pd.read_csv('./data/all_tracts.csv')

# %%
tracts_df
# Out:
#               GEOID  year  name                     parent.location  \
# 0        2013000100  2009  1.00      Aleutians East Borough, Alaska
# 1        2013000100  2010  1.00      Aleutians East Borough, Alaska
# 2        2013000100  2013  1.00      Aleutians East Borough, Alaska
# 3        2013000100  2015  1.00      Aleutians East Borough, Alaska
# 4        2016000100  2016  1.00  Aleutians West Census Area, Alaska
# ...             ...   ...   ...                                 ...
# 250634  56043000301  2016  3.01            Washakie County, Wyoming
# 250635  56043000302  2013  3.02            Washakie County, Wyoming
# 250636  56043000302  2014  3.02            Washakie County, Wyoming
# 250637  56043000302  2015  3.02            Washakie County, Wyoming
# 250638  56043000302  2016  3.02            Washakie County, Wyoming
#
#         population  poverty.rate  renter.occupied.households  \
# 0           2959.0          8.37                       263.0
# 1           3141.0          6.28                       268.0
# 2           3304.0         12.74                       274.0
# 3           3304.0         12.74                       278.0
# 4           1065.0         12.43                       128.0
# ...            ...           ...                         ...
# 250634      2578.0          5.91                       379.0
# 250635      2566.0          8.99                       256.0
# 250636      2566.0          8.99                       261.0
# 250637      2566.0          8.99                       266.0
# 250638      2566.0          8.99                       271.0
#
#         pct.renter.occupied  median.gross.rent  median.household.income  ...  \
# 0                     58.59              654.0                  56250.0  ...
# 1                     48.46              847.0                  58125.0  ...
# 2                     46.52              930.0                  61518.0  ...
# 3                     46.52              930.0                  61518.0  ...
# 4                     41.67              934.0                  57500.0  ...
# ...                     ...                ...                      ...  ...
# 250634                37.40              634.0                  34643.0  ...
# 250635                24.76              543.0                  55192.0  ...
# 250636                24.76              543.0                  55192.0  ...
# 250637                24.76              543.0                  55192.0  ...
# 250638                24.76              543.0                  55192.0  ...
#
#         pct.nh.pi  pct.multiple  pct.other  eviction.filings  evictions  \
# 0            0.34          5.58       0.14               0.0        NaN
# 1            0.60          3.72       0.03               0.0        NaN
# 2            1.12          3.18       0.00               0.0        NaN
# 3            1.12          3.18       0.00               0.0        NaN
# 4            3.76          2.82       0.56               0.0        NaN
# ...           ...           ...        ...               ...        ...
# 250634       0.00          2.83       0.00               2.0        2.0
# 250635       0.00          4.21       0.00               1.0        1.0
# 250636       0.00          4.21       0.00               2.0        2.0
# 250637       0.00          4.21       0.00               0.0        0.0
# 250638       0.00          4.21       0.00               1.0        1.0
#
#         eviction.rate  eviction.filing.rate  low.flag  imputed  subbed
# 0                 NaN                  0.00         0        0       1
# 1                 NaN                  0.00         0        0       1
# 2                 NaN                  0.00         0        0       1
# 3                 NaN                  0.00         0        0       1
# 4                 NaN                  0.00         0        0       1
# ...               ...                   ...       ...      ...     ...
# 250634           0.53                  0.53         0        0       0
# 250635           0.39                  0.39         0        0       0
# 250636           0.77                  0.77         0        0       0
# 250637           0.00                  0.00         0        0       0
# 250638           0.37                  0.37         0        0       0
#
# [250639 rows x 27 columns]

# %%
tracts_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250639 entries, 0 to 250638
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   GEOID                       250639 non-null  int64
#  1   year                        250639 non-null  int64
#  2   name                        250639 non-null  float64
#  3   parent.location             250639 non-null  object
#  4   population                  250607 non-null  float64
#  5   poverty.rate                250607 non-null  float64
#  6   renter.occupied.households  250609 non-null  float64
#  7   pct.renter.occupied         250607 non-null  float64
#  8   median.gross.rent           247914 non-null  float64
#  9   median.household.income     249288 non-null  float64
#  10  median.property.value       248169 non-null  float64
#  11  rent.burden                 248476 non-null  float64
#  12  pct.white                   250607 non-null  float64
#  13  pct.af.am                   250607 non-null  float64
#  14  pct.hispanic                250607 non-null  float64
#  15  pct.am.ind                  250607 non-null  float64
#  16  pct.asian                   250607 non-null  float64
#  17  pct.nh.pi                   250607 non-null  float64
#  18  pct.multiple                250607 non-null  float64
#  19  pct.other                   250607 non-null  float64
#  20  eviction.filings            248004 non-null  float64
#  21  evictions                   246690 non-null  float64
#  22  eviction.rate               246690 non-null  float64
#  23  eviction.filing.rate        248004 non-null  float64
#  24  low.flag                    250639 non-null  int64
#  25  imputed                     250639 non-null  int64
#  26  subbed                      250639 non-null  int64
# dtypes: float64(21), int64(5), object(1)
# memory usage: 51.6+ MB

# %% [markdown]
# # Cleaning

# %% [markdown]
# ### Dropping States

# %% [markdown]
# Dropping due to missing years of data
# 1. ND
# 2. SD
# 3. AK
# 4. SC
# 5. NJ
# 6. MA
# 7. CT
# 8. RI
# 9. NH

# %%
drop_state_list = ['North Dakota', 'South Dakota', 'Arkansas', 
                   'South Carolina', 'New Jersey', 'Massachusetts',
                  'Connecticut', 'Rhode Island', 'New Hampshire']

for state in drop_state_list:
    drop_indices = tracts_df[tracts_df['parent.location'].str.contains(state)].index
    tracts_df.drop(drop_indices, inplace=True)

# %% [markdown]
# ### Creating 'States' & 'County' Column

# %%
tracts_df['state'] = tracts_df['parent.location'].str.rpartition(', ')[2]

tracts_df['county'] = tracts_df['parent.location'].str.rpartition(', ')[0]

tracts_df.drop('parent.location', axis=1, inplace=True)

# %% [markdown]
# 1. 'county' may be an interesting feature for EDA, however it will create too many dummy variables during modeling

# %% [markdown]
# ### Differentiating Census Tracts by State

# %% [markdown]
# Census tracts are unique ONLY within each State, so I will add the name of the corresponding state to each census tract

# %%
tracts_df['name'] = tracts_df['name'].astype(str)+'_'+tracts_df['state']

# %% [markdown]
# ### Cleaning Null Target Variables

# %%
null_er_df = tracts_df[tracts_df['eviction.rate'].isna()]

# %%
null_er_df.shape
# Out:
# (2195, 28)

# %%
null_er_df[null_er_df['state'] == 'Alaska'].shape[0] == tracts_df[tracts_df['state'] == 'Alaska'].shape[0]
# Out:
# True

# %% [markdown]
# 1. Alaska has no 'eviction.rate' data and must be dropped

# %%
tract_groupby = tracts_df.groupby(['name']).median()

# %%
tract_groupby
# Out:
#                         GEOID    year  population  poverty.rate  \
# name
# 1.01_California  6.105000e+09  2010.5      2747.5        15.930
# 1.01_Florida     1.208100e+10  2010.5      3222.0        10.325
# 1.01_Georgia     1.313900e+10  2003.0      3796.0        10.060
# 1.01_Iowa        1.915300e+10  2006.0      3194.0        24.430
# 1.01_Kentucky    2.106700e+10  2009.0      3415.5        25.455
# ...                       ...     ...         ...           ...
# 997.05_New York  3.608110e+10  2015.0      2720.0         6.710
# 998.01_New York  3.608110e+10  2015.0      7455.0        16.150
# 998.02_New York  3.608110e+10  2015.0      5391.0        12.100
# 998.0_New York   3.604710e+10  2005.0      3207.0        14.200
# 999.0_New York   3.608110e+10  2015.0         0.0         0.000
#
#                  renter.occupied.households  pct.renter.occupied  \
# name
# 1.01_California                       300.0                22.77
# 1.01_Florida                          900.5                61.64
# 1.01_Georgia                          326.0                20.39
# 1.01_Iowa                             844.0                68.21
# 1.01_Kentucky                        1630.5                84.10
# ...                                     ...                  ...
# 997.05_New York                       370.0                30.08
# 998.01_New York                      1985.0                72.14
# 998.02_New York                      2431.0                91.51
# 998.0_New York                        658.0                50.90
# 999.0_New York                          0.0                 0.00
#
#                  median.gross.rent  median.household.income  \
# name
# 1.01_California              872.0                  33489.5
# 1.01_Florida                 913.0                  31684.0
# 1.01_Georgia                 540.0                  43861.0
# 1.01_Iowa                    641.0                  27895.0
# 1.01_Kentucky                465.0                  19149.0
# ...                            ...                      ...
# 997.05_New York             2256.0                  71310.0
# 998.01_New York             1133.0                  61434.0
# 998.02_New York             1003.0                  34287.0
# 998.0_New York              1253.0                  46719.0
# 999.0_New York                 NaN                      NaN
#
#                  median.property.value  rent.burden  ...  pct.nh.pi  \
# name                                                 ...
# 1.01_California             245000.085        45.45  ...      0.085
# 1.01_Florida                162600.000        43.55  ...      0.000
# 1.01_Georgia                 96700.000        20.70  ...      0.010
# 1.01_Iowa                   112800.000        31.10  ...      0.000
# 1.01_Kentucky               138500.000        31.00  ...      0.060
# ...                                ...          ...  ...        ...
# 997.05_New York             625300.000        14.60  ...      0.000
# 998.01_New York             385500.000        25.40  ...      0.000
# 998.02_New York             342800.000        33.40  ...      0.000
# 998.0_New York              537700.000        34.00  ...      0.000
# 999.0_New York                     NaN          NaN  ...      0.000
#
#                  pct.multiple  pct.other  eviction.filings  evictions  \
# name
# 1.01_California         2.535       0.05               6.5        6.5
# 1.01_Florida            1.790       0.09              30.0       12.0
# 1.01_Georgia            0.410       0.09              75.0       51.0
# 1.01_Iowa               3.600       0.00             102.0       31.0
# 1.01_Kentucky           2.290       0.36             103.5       65.0
# ...                       ...        ...               ...        ...
# 997.05_New York         1.840       0.00               NaN        NaN
# 998.01_New York         0.380       0.64               NaN        NaN
# 998.02_New York         0.820       0.00               NaN        NaN
# 998.0_New York          0.000       0.00              29.0       11.0
# 999.0_New York          0.000       0.00               NaN        NaN
#
#                  eviction.rate  eviction.filing.rate  low.flag  imputed  \
# name
# 1.01_California          2.165                 2.165       0.0      0.0
# 1.01_Florida             1.165                 3.155       0.0      0.0
# 1.01_Georgia            15.670                23.040       0.0      0.0
# 1.01_Iowa                3.450                10.520       0.0      0.0
# 1.01_Kentucky            3.995                 6.355       0.0      0.0
# ...                        ...                   ...       ...      ...
# 997.05_New York            NaN                   NaN       0.0      0.0
# 998.01_New York            NaN                   NaN       0.0      0.0
# 998.02_New York            NaN                   NaN       0.0      0.0
# 998.0_New York           1.680                 4.390       0.0      0.0
# 999.0_New York             NaN                   NaN       0.0      0.0
#
#                  subbed
# name
# 1.01_California     0.0
# 1.01_Florida        0.0
# 1.01_Georgia        0.0
# 1.01_Iowa           0.0
# 1.01_Kentucky       0.0
# ...                 ...
# 997.05_New York     0.0
# 998.01_New York     0.0
# 998.02_New York     0.0
# 998.0_New York      0.0
# 999.0_New York      0.0
#
# [26804 rows x 25 columns]

# %%
tract_groupby[tract_groupby['eviction.rate'].isna()]

# %% [markdown]
# 1. 437 Census Tracts have no data for 'eviction.rate', so I will be dropping them

# %%
tract_groupby.reset_index(inplace=True)

# %%
tract_groupby.name[0]

# %%
drop_tract_list = []
for i in range(tract_groupby.shape[0]):
    drop_tract_list.append(tract_groupby.name[i])

# %%
drop_tract_list
