# %%
import pandas as pd
import glob as glob
import os

# %%
al_2013 = pd.read_csv('./data/employment_status/AL_2013.csv')

# %%
al_2013.drop(0, inplace=True)

# %%
al_2013['']
# Out:
#                      GEO_ID  \
# 1     1500000US010010201001
# 2     1500000US010010201002
# 3     1500000US010010202001
# 4     1500000US010010202002
# 5     1500000US010010203001
# ...                     ...
# 3434  1500000US011339658004
# 3435  1500000US011339658005
# 3436  1500000US011339659001
# 3437  1500000US011339659002
# 3438  1500000US011339659003
#
#                                                    NAME B99231_001E  \
# 1     Block Group 1, Census Tract 201, Autauga Count...         425
# 2     Block Group 2, Census Tract 201, Autauga Count...         979
# 3     Block Group 1, Census Tract 202, Autauga Count...        1034
# 4     Block Group 2, Census Tract 202, Autauga Count...         924
# 5     Block Group 1, Census Tract 203, Autauga Count...        1876
# ...                                                 ...         ...
# 3434  Block Group 4, Census Tract 9658, Winston Coun...         495
# 3435  Block Group 5, Census Tract 9658, Winston Coun...         396
# ...

# %%
al_2013.drop(['NAME', 'B99231_002E', 'B99231_003E'], axis=1, inplace=True)

# %%
al_2013
# Out:
#                      GEO_ID B99231_001E
# 1     1500000US010010201001         425
# 2     1500000US010010201002         979
# 3     1500000US010010202001        1034
# 4     1500000US010010202002         924
# 5     1500000US010010203001        1876
# ...                     ...         ...
# 3434  1500000US011339658004         495
# 3435  1500000US011339658005         396
# 3436  1500000US011339659001         477
# 3437  1500000US011339659002         672
# 3438  1500000US011339659003         634
#
# [3438 rows x 2 columns]

# %%
al_2014 = pd.read_csv('./data/employment_status/AL_2014.csv')

# %%
al_2014
# Out:
#                      GEO_ID  \
# 0                        id
# 1     1500000US010010201001
# 2     1500000US010010201002
# 3     1500000US010010202001
# 4     1500000US010010202002
# ...                     ...
# 3434  1500000US011339658004
# 3435  1500000US011339658005
# 3436  1500000US011339659001
# 3437  1500000US011339659002
# 3438  1500000US011339659003
#
#                                                    NAME      B99231_001E  \
# 0                                  Geographic Area Name  Estimate!!Total
# 1     Block Group 1, Census Tract 201, Autauga Count...              457
# 2     Block Group 2, Census Tract 201, Autauga Count...             1035
# 3     Block Group 1, Census Tract 202, Autauga Count...              992
# 4     Block Group 2, Census Tract 202, Autauga Count...              945
# ...                                                 ...              ...
# 3434  Block Group 4, Census Tract 9658, Winston Coun...              525
# ...

# %%
combined = pd.concat([al_2013, al_2014])

# %%
combined
# Out:
#                      GEO_ID  \
# 0                        id
# 1     1500000US010010201001
# 2     1500000US010010201002
# 3     1500000US010010202001
# 4     1500000US010010202002
# ...                     ...
# 3434  1500000US011339658004
# 3435  1500000US011339658005
# 3436  1500000US011339659001
# 3437  1500000US011339659002
# 3438  1500000US011339659003
#
#                                                    NAME      B99231_001E  \
# 0                                  Geographic Area Name  Estimate!!Total
# 1     Block Group 1, Census Tract 201, Autauga Count...              425
# 2     Block Group 2, Census Tract 201, Autauga Count...              979
# 3     Block Group 1, Census Tract 202, Autauga Count...             1034
# 4     Block Group 2, Census Tract 202, Autauga Count...              924
# ...                                                 ...              ...
# 3434  Block Group 4, Census Tract 9658, Winston Coun...              525
# ...
